# %% [markdown]
# ngram
# ===
#
# 统计ngram，并进行简单的文本生成
#
# ![Snip20191021_12.png](https://i.loli.net/2019/10/21/bcq7uEPMCei1F5I.png)
# ![Snip20191021_13.png](https://i.loli.net/2019/10/21/q2USxHT3wLQiAOZ.png)

# %%
import random
import jieba

# %%
corpus_file = open("../input/santi.txt", "r", encoding="utf-8")
raw_text = corpus_file.readlines()
text = ""
for line in raw_text:
    text += line.strip()
corpus_file.close()
# 选择分词或者是分字
split_mode = "jieba"
if split_mode == "char":
    token_list = [char for char in text]
# 利用jieba库分词
elif split_mode == "jieba":
    token_list = [word for word in jieba.cut(text)]
# 确定ngram的历史检索长度，即n
ngram_len = 4
# Out:
# Building prefix dict from the default dictionary ...
# Loading model from cache C:\Users\ELENST~1\AppData\Local\Temp\jieba.cache
# Loading model cost 1.818 seconds.
# Prefix dict has been built successfully.

# %%
# 初始化ngram词典
ngram_dict = {}
for i in range(1, ngram_len): # i = 1 2 3
    for j in range(len(token_list) - i - 1):
        # 统计前缀是[j, j+i]个词的时候第j+i+1个词出现的次数
        key = "".join(token_list[j: j + i + 1])
        value = "".join(token_list[j + i + 1])
        # 为第一次出现的键建立字典
        if key not in ngram_dict:
            ngram_dict[key] = {}
        # 初始化字典内每个键值对映射的计数器
        if value not in ngram_dict[key]:
            ngram_dict[key][value] = 0
        ngram_dict[key][value] += 1

# %%
ngram_dict
# Out:
# {'==': {'=': 128, '本站': 2, '《': 1},
#  '=本站': {'作品': 2},
#  '本站作品': {'仅供': 2},
#  '作品仅供': {'试阅': 2},
#  '仅供试阅': {'，': 2},
#  '试阅，': {'版权': 2},
#  '，版权': {'归': 2},
#  '版权归': {'原作者': 2},
#  '归原作者': {'所有': 2},
#  '原作者所有': {'，': 2},
#  '所有，': {'下载': 2},
#  '，下载': {'后': 2},
#  '下载后': {'请': 2},
#  '后请': {'于': 2, '他': 1},
#  '请于': {'24': 2},
#  '于24': {'小时': 2},
#  '24小时': {'内': 2},
#  '小时内': {'删除': 2},
#  '内删除': {'，': 2},
#  '删除，': {'如': 2},
#  '，如': {'喜欢': 2,
#   '他': 1,
#   '打电话': 1,
#   '微风': 1,
#   '陨石': 1,
#   '一条': 1,
#   '一阵': 1,
#   '闪电般': 1,
#   '暴雨': 1,
#   '无': 1,
#   '太空城': 1,
#   '漆黑': 1,
#   '一道': 1,
#   '结冰': 1,
#   '维纳斯': 1,
#   '万箭穿心': 1,
#   '摩天大楼': 1,
#   '轮辐': 1,
#   '仇恨': 1},
#  '如喜欢': {'请': 2},
#  '喜欢请': {'购买': 2},
#  '请购买': {'正版': 2},
#  '购买正版': {'！': 2},
#  '正版！': {'购买': 2},
#  '！购买': {'地址': 2},
#  '购买地址': {'：': 2},
#  '地址：': {'https': 2, 'http': 2},
#  '：https': {':': 2},
#  'https:': {'/': 2},
#  ':/': {'/': 4},
#  '//': {'union': 2, 'blog': 2},
#  '/union': {'-': 2},
#  'union-': {'click': 2},
#  '-click': {'.': 2},
#  'click.': {'jd': 2},
#  '.jd': {'.': 2},
#  'jd.': {'com': 2},
#  '.com': {'/': 2, '.': 2},
#  'com/': {'jdc': 2},
#  '/jdc': {'?': 2},
#  'jdc?': {'d': 2},
#  '?d': {'=': 2},
#  'd=': {'cYdwuEPDF': 2},
#  '=cYdwuEPDF': {'免费': 2},
#  'cYdwuEPDF免费': {'下载': 2},
#  '免费下载': {'地址': 2},
#  '下载地址': {'：': 2},
#  '：http': {':': 2},
#  'http:': {'/': 2},
#  '/blog': {'.': 2},
#  'blog.': {'sina': 2},
#  '.sina': {'.': 2},
#  'sina.': {'com': 2},
#  'com.': {'cn': 2},
#  '.cn': {'/': 2},
#  'cn/': {'u': 2},
#  '/u': {'/': 2},
#  'u/': {'6494397230': 2},
#  '/6494397230': {'=': 2},
#  '6494397230=': {'=': 2},
#  '=《': {'三体': 1},
#  '《三体': {'III': 62, '》': 8, 'II': 8},
#  '三体III': {'：': 53, '》': 9},
#  'III：': {'死神': 53},
#  '：死神': {'永生': 53},
#  '死神永生': {'》': 53, '。': 1},
#  '永生》': {'作者': 1, ' ': 52},
#  '》作者': {'：': 1},
#  '作者：': {'刘慈欣': 53},
#  '：刘慈欣': {'前言': 1,
#   '心事': 1,
#   '序当': 1,
#   '纪年': 1,
#   '第一部': 1,
#   '第一章': 1,
#   '第二章': 6,
#   '第三章': 6,
#   '第四章': 5,
#   '第五章': 4,
#   '第六章': 3,
#   '第七章': 3,
#   '第八章': 3,
#   '第二部': 1,
#   '第九章': 2,
#   '第十章': 2,
#   '第十一章': 2,
#   '第十二章': 2,
#   '第十三章': 1,
#   '第十四章': 1,
#   '第十五章': 1,
#   '第三部': 1,
#   '第四部': 1,
#   '第五部': 1,
#   '第六部': 1,
#   '=': 1},
#  '刘慈欣前言': {'写': 1},
#  '前言写': {'在': 1},
#  '写在': {'“': 1, '古': 1},
#  '在“': {'基石': 1,
#   '青铜时代': 1,
#   '万有引力': 4,
#   '蓝色': 4,
#   '魔戒': 1,
#   '绿色': 1,
#   '井': 1,
#   '木星': 1,
#   '地面': 1,
#   '启示': 2,
#   '他们': 1,
#   '年轮': 1,
#   '星环': 4},
#  '“基石': {'”': 3},
#  '基石”': {'之前': 1, '是': 1, '。': 1},
#  '”之前': {'姚': 1},
#  '之前姚': {'海军': 1},
#  '姚海军': {'“': 1},
#  '海军“': {'基石': 1},
#  '”是': {'个': 1,
#   '宇航': 1,
#   '的': 2,
#   '封闭': 1,
#   '全封闭': 1,
#   '重点': 1,
#   '看不到': 2,
#   '啊': 1,
#   '什么': 1,
#   '一个': 1},
#  '是个': {'平实': 1,
#   '好时光': 1,
#   '精明': 1,
#   '令': 1,
#   '很': 1,
#   '有': 1,
#   '外人': 1,
#   '像': 1,
#   '机器人': 1,
#   '老成持重': 1,
#   '谜': 4,
#   '舒服': 1,
#   '习惯性': 1,
#   '魔鬼': 1,
#   '好': 3,
#   '巨人': 1,
#   '设计': 1,
#   '幻觉': 1,
#   '空壳': 1,
#   '成功': 1,
#   '危险': 1,
#   '美人': 1,
#   '伟大': 1,
#   '里程碑': 1,
#   '多么': 1,
#   '映像': 1,
#   '合格': 1,
#   '相当': 1},
#  '个平实': {'的': 1},
#  '平实的': {'词': 1},
#  '的词': {'，': 2, '像': 1},
#  '词，': {'不够': 1, '这是': 1, 'IDC': 1, '赫尔辛': 1},
#  '，不够': {'“': 1},
#  '不够“': {'炫': 1},
#  '“炫': {'”': 1},
#  '炫”': {'却': 1},
#  '”却': {'能够': 1},
#  '却能够': {'准确': 1, '被': 1},
#  '能够准确': {'传达': 1},
#  '准确传达': {'我们': 1},
#  '传达我们': {'对': 1},
#  '我们对': {'构建': 1, '您': 1, '烧': 1},
#  '对构建': {'中': 1},
#  '构建中': {'的': 1},
#  '中的': {'中国': 1,
#   '人物': 1,
#   '物质': 3,
#   '人': 7,
#   '一个': 15,
#   '小草': 1,
#   '西欧': 1,
#   '财富': 1,
#   '几': 1,
#   '生命': 2,
#   '宇宙': 1,
#   '彼岸': 1,
#   '水成': 1,
#   '湖畔': 1,
#   '问题': 1,
#   '差不多': 1,
#   '景象': 2,
#   '还': 1,
#   '阴冷': 1,
#   '地球': 3,
#   '五分之一': 1,
#   '每个': 1,
#   '人体': 1,
#   '也': 1,
#   '轰鸣声': 1,
#   '一小部分': 2,
#   '他': 1,
#   '容器': 1,
#   '东西': 4,
#   '候选人': 1,
#   '实体': 1,
#   '什么': 1,
#   '这': 2,
#   '主流': 1,
#   '精灵': 1,
#   '最大': 1,
#   '1974': 1,
#   '十颗': 1,
#   '相会': 1,
#   '长江': 1,
#   '清': 1,
#   '深意': 2,
#   '男性': 1,
#   '美丽': 1,
#   '任何人': 1,
#   '第二任': 1,
#   '鹰派': 1,
#   '宝宝': 1,
#   '幻觉': 1,
#   '大部分': 4,
#   '直觉': 1,
#   '一只': 1,
#   '太空': 4,
#   '世界': 4,
#   '负面': 1,
#   '死尸': 1,
#   '“': 2,
#   '两个': 2,
#   '水': 3,
#   '地面': 1,
#   '二十个': 1,
#   '一百个': 1,
#   '东方': 1,
#   '航迹': 2,
#   '一片': 2,
#   '可': 1,
#   '强互': 1,
#   '居住': 1,
#   '移民区': 1,
#   '一切': 3,
#   '人类': 3,
#   '八个': 1,
#   '移民': 1,
#   '半个': 1,
#   '米粒': 1,
#   '一部分': 2,
#   '休': 1,
#   '男': 1,
#   '湖面': 1,
#   '古代': 1,
#   '含义': 2,
#   '长明灯': 1,
#   '玲子': 1,
#   '水滴': 2,
#   '许多': 1,
#   '旧': 1,
#   '震撼': 1,
#   '一阵': 1,
#   '所有人': 1,
#   '中下层': 1,
#   '一名': 1,
#   '一张': 2,
#   '熟悉': 1,
#   '空气': 2,
#   '每面': 1,
#   '人们': 9,
#   '光学': 1,
#   '空间': 2,
#   '四维': 1,
#   '三维': 2,
#   '点阵': 1,
#   '相应': 2,
#   '水面': 1,
#   '一台': 1,
#   '谋杀': 1,
#   '落选者': 1,
#   '一种': 2,
#   '树林': 1,
#   '声音': 2,
#   '一颗': 3,
#   '世界性': 1,
#   '清泉': 1,
#   '行星': 1,
#   '毁灭': 1,
#   '无数': 1,
#   '生存': 2,
#   '文明': 2,
#   '所有': 6,
#   '两万多': 1,
#   '人口数量': 1,
#   '十字架': 1,
#   '母爱': 1,
#   '寂静': 1,
#   '重力': 3,
#   '居民': 1,
#   '流线型': 1,
#   '惯例': 1,
#   '日出': 1,
#   '巨型': 1,
#   '自己': 2,
#   '大脑': 1,
#   '走向': 1,
#   '绿': 1,
#   '两位': 2,
#   '智子': 2,
#   '陌路': 1,
#   '静电': 2,
#   '另': 1,
#   '人民': 1,
#   '灯火': 1,
#   '画': 1,
#   '生活': 4,
#   '水里': 1,
#   '饕餮': 1,
#   '泡泡': 2,
#   '每': 4,
#   '朝圣': 1,
#   '露珠': 1,
#   '遭遇': 1,
#   '绝大部分': 1,
#   '各种': 1,
#   '资源': 1,
#   '神奇': 1,
#   '时候': 1,
#   '一样': 1,
#   '下午': 1,
#   '前景': 1,
#   '大学': 1,
#   '飞船': 1,
#   '隐喻': 1,
#   '地位': 1,
#   '其他': 2,
#   '伞': 1,
#   '一座': 1,
#   '一句': 1,
#   '彩虹': 1,
#   '光速': 4,
#   '颠沛流离': 1,
#   '电子计算机': 1,
#   '近地': 1,
#   '飞行': 1,
#   '人群': 2,
#   '尾迹': 1,
#   '昂贵': 1,
#   '争相': 1,
#   '恐怖': 1,
#   '光粒': 1,
#   '常驻': 1,
#   '天文学家': 1,
#   '恐惧': 1,
#   '发现': 2,
#   '脆弱': 1,
#   '广袤': 1,
#   '这个': 1,
#   '动作': 1,
#   '程心': 2,
#   'AA': 1,
#   '人造': 1,
#   '乘客': 1,
#   '活动': 1,
#   '随': 1,
#   '公路': 1,
#   '建筑': 2,
#   '光': 1,
#   '魔鬼': 1,
#   '高': 1,
#   '废墟': 1,
#   '一圈': 1,
#   '升降梯': 1,
#   '小': 2,
#   '约束': 1,
#   '城市': 1,
#   '自由人': 2,
#   '三支': 1,
#   '艾': 1,
#   '低': 1,
#   '几十个': 1,
#   '任何': 3,
#   '故事': 1,
#   '沙漠': 1,
#   '磷火': 1,
#   '分形': 1,
#   '制热': 1,
#   '卢梭': 1,
#   '一点': 1,
#   '六百多': 1,
#   '二维': 2,
#   '这座': 1,
#   '没有': 1,
#   '蚁': 1,
#   '人形': 1,
#   '变形': 1,
#   '文物': 1,
#   '不同': 1,
#   '导航': 1,
#   '太阳': 1,
#   '水远': 1,
#   '雪': 1,
#   '一幅': 1,
#   '罗辑': 1,
#   '停止': 1,
#   '蓝草': 1,
#   '冰湖': 1,
#   '物理学': 1,
#   '自责': 1,
#   '一点儿': 1,
#   '火焰': 1,
#   '化学': 1,
#   '电源': 1,
#   '星星': 1,
#   '含氧量': 1,
#   '屏幕': 1,
#   '他们': 2,
#   '机器人': 1,
#   '一年': 1,
#   '热量': 1,
#   '监测': 1,
#   '水声': 1,
#   '质量': 2,
#   '内容': 1,
#   '滚动': 1,
#   '门': 1,
#   '十几个': 1,
#   '场景': 1,
#   '记忆体': 1},
#  '的中国': {'科幻': 1, '版': 1, '文学': 1, '神话': 1, '同胞': 1, '剑术': 1},
#  '中国科幻': {'繁华': 1, '与': 1, '的': 1, '需要': 1, '补课': 1},
#  '科幻繁华': {'巨厦': 1},
#  '繁华巨厦': {'的': 1},
#  '巨厦的': {'情感': 1},
#  '的情感': {'与': 1, '在': 1, '再次': 1},
#  '情感与': {'信心': 1},
#  '与信心': {'，': 1},
#  '信心，': {'因此': 1, '谢谢': 1},
#  '，因此': {'，': 4, '这个': 1, '又称': 1},
#  '因此，': {'我们': 1, '减少': 1, '三个': 1, '它': 1},
#  '，我们': {'用': 1,
#   '基本上': 1,
#   '并': 1,
#   '满怀': 1,
#   '这些': 1,
#   '觉得': 1,
#   '又': 1,
#   '也': 5,
#   '看到': 2,
#   '的': 10,
#   '就': 6,
#   '不': 4,
#   '不会': 1,
#   '对': 1,
#   '得': 3,
#   '应该': 2,
#   '可不': 1,
#   '要': 5,
#   '只能': 4,
#   '有': 2,
#   '女人': 1,
#   '是': 3,
#   '只': 1,
#   '都': 6,
#   '还有': 2,
#   '已经': 1,
#   '曾经': 1,
#   '这个': 1,
#   '与': 4,
#   '这里': 1,
#   '仍然': 1,
#   '将': 2,
#   '发射': 1,
#   '举行': 1,
#   '把': 1,
#   '现在': 4,
#   '需要': 1,
#   '自身': 1,
#   '可以': 2,
#   '猜测': 1,
#   '怎么': 2,
#   '却': 1,
#   '未来': 1,
#   '在': 4,
#   '能': 1,
#   '不谈': 1,
#   '常常': 1,
#   '一定': 1,
#   '本来': 1,
#   '对视': 1,
#   '只是': 1,
#   '一致': 1,
#   '继续': 1,
#   '俩': 3,
#   '走': 3,
#   '好像': 1,
#   '到': 2,
#   '永远': 1,
#   '必须': 1,
#   '这': 2,
#   '一点': 1,
#   '等': 1,
#   '、': 1,
#   '承担': 1,
#   '各': 1,
#   '出去': 2,
#   '拥有': 1,
#   '会': 3,
#   '一无所知': 1,
#   '虽': 1,
#   '曾': 1,
#   '还是': 1,
#   '担心': 1,
#   '该': 1,
#   '去': 2,
#   '才能': 1,
#   '通常': 1,
#   '有个': 1,
#   '见': 1,
#   '欢迎': 1,
#   '大脑': 1,
#   '以前': 1,
#   '马上': 1,
#   '尽快': 1,
#   '陷在': 1,
#   '随时': 1,
#   '错过': 1,
#   '真的': 1,
#   '处于': 1,
#   '能够': 1,
#   '不是': 1,
#   '知道': 1},
#  '我们用': {'它': 1, '资源': 1, '了': 1},
#  '用它': {'来': 2, '的': 1, '去': 1, '处理': 1},
#  '它来': {'作为': 1, '调侃': 1, '做': 1},
#  '来作为': {'这套': 1},
#  '作为这套': {'原创': 1},
#  '这套原创': {'丛书': 1},
#  '原创丛书': {'的': 1},
#  '丛书的': {'名字': 1},
#  '的名字': {'。': 4, '也': 1, '，': 7, '在': 1},
#  '名字。': {'最近': 1, '这': 1, '是': 1, '放在': 1},
#  '。最近': {'十年': 1, '，': 1, '的': 1},
#  '最近十年': {'，': 1},
#  '十年，': {'是': 1, '深得': 1},
#  '，是': {'科幻': 1,
#   '以': 1,
#   '奥斯曼帝国': 1,
#   '空': 1,
#   '唯一': 1,
#   '生命': 1,
#   '为了': 5,
#   '一支': 1,
#   '，': 1,
#   '大学': 1,
#   '那种': 2,
#   '实干家': 1,
#   '提议': 1,
#   '它': 1,
#   '直接': 1,
#   '柯曼琳': 1,
#   '一个': 8,
#   '吧': 4,
#   '之前': 1,
#   '。': 1,
#   '控制': 1,
#   '的': 2,
#   '所有': 3,
#   '一名': 3,
#   '冬眠': 1,
#   'AA': 2,
#   '为': 2,
#   '怎么': 1,
#   '围绕': 1,
#   '已经': 1,
#   '迷蒙': 1,
#   '什么': 1,
#   '毛利人': 1,
#   '二战时期': 1,
#   '距': 1,
#   '说': 2,
#   '澳大利亚': 1,
#   '在': 3,
#   '人类': 2,
#   '市政府': 1,
#   '这个': 3,
#   '一部': 1,
#   '那个': 3,
#   '不': 1,
#   '自己': 1,
#   '一位': 1,
#   '他': 1,
#   '我们': 1,
#   '原速': 1,
#   '他们': 3,
#   '不能': 1,
#   '踏': 1,
#   '太阳升': 1,
#   '细节': 1,
#   '完全': 1,
#   '“': 1,
#   '突然': 1,
#   '真正': 1,
#   '这样': 1,
#   '类似': 2,
#   '一颗': 1,
#   '指': 3,
#   '母爱': 1,
#   '不想': 1,
#   '智子': 1,
#   '一次': 2,
#   '公元': 1,
#   '纯': 1,
#   '用': 3,
#   '严重': 1,
#   '一件': 1,
#   '眼前': 1,
#   '维德': 1,
#   '作为': 1,
#   '空灵': 1,
#   '那里': 2,
#   '某种': 1,
#   '黑曜石': 1,
#   '船': 1,
#   '海浪': 1,
#   '我': 2,
#   '一种': 1,
#   '世界': 2,
#   '完好无损': 1,
#   '二十年': 1,
#   '黑压压': 1,
#   '刚刚': 1,
#   '幅': 1,
#   '黑色': 1,
#   '车': 1,
#   '古代': 1,
#   '最最': 1,
#   '新建': 1,
#   '根据': 1,
#   '尘埃': 1,
#   '充满': 1,
#   '紧靠着': 1,
#   '护士': 1,
#   '向上': 1,
#   '太空城': 1,
#   '最小': 1,
#   '一片': 2,
#   '球体': 1,
#   '人口': 1,
#   '木星': 1,
#   '掩体': 1,
#   '开拓': 1,
#   '一根': 1,
#   '中国': 1,
#   '研究': 1,
#   '座': 1,
#   '真的': 1,
#   '太阳系外': 1,
#   '一艘': 1,
#   '封装': 1,
#   '一年': 1,
#   '危机': 1,
#   '22': 1,
#   '累': 1,
#   '太阳系': 1,
#   '恐龙': 1,
#   '古希腊': 1,
#   '土星': 1,
#   '二维': 2,
#   '七个': 1,
#   '小': 1,
#   '那条': 1,
#   '想': 1,
#   '慢': 1,
#   '前者': 1,
#   '着陆': 1,
#   '它们': 1,
#   '十维': 1,
#   '离开': 1,
#   '她': 1,
#   '低': 1,
#   '许多': 1,
#   '一份': 1,
#   '怎样': 2,
#   '云': 1,
#   '怕': 1,
#   '要': 1,
#   '程心': 1},
#  '是科幻': {'创作': 1},
#  '科幻创作': {'飞速发展': 1},
#  '创作飞速发展': {'的': 1},
#  '飞速发展的': {'十年': 1},
#  '的十年': {'。': 1, '中': 1},
#  '十年。': {'王晋康': 1},
#  '。王晋康': {'、': 1},
#  '王晋康、': {'刘慈欣': 1},
#  '、刘慈欣': {'、': 1},
#  '刘慈欣、': {'何': 1},
#  '、何': {'宏伟': 1},
#  '何宏伟': {'、': 1},
#  '宏伟、': {'韩松': 1},
#  '、韩松': {'等': 1},
#  '韩松等': {'一大批': 1},
#  '等一大批': {'科幻': 1},
#  '一大批科幻': {'作家': 1},
#  '科幻作家': {'发表': 1, '，': 1, '。': 1},
#  '作家发表': {'了': 1},
#  '发表了': {'大量': 1, '一个': 1},
#  '了大量': {'深受': 1, '聚变': 1, '的': 7, '研究': 1},
#  '大量深受': {'读者': 1},
#  '深受读者': {'喜爱': 1},
#  '读者喜爱': {'、': 1},
#  '喜爱、': {'极具': 1},
#  '、极具': {'开拓': 1},
#  '极具开拓': {'与': 1},
#  '开拓与': {'探索': 1},
#  '与探索': {'价值': 1},
#  '探索价值': {'的': 1},
#  '价值的': {'科幻': 1, '东西': 2},
#  '的科幻': {'佳作': 1, '走向': 1, '作家': 2, '界': 1},
#  '科幻佳作': {'。': 1},
#  '佳作。': {'科幻': 1},
#  '。科幻': {'文学': 1, '图书': 1},
#  '科幻文学': {'的': 2},
#  '文学的': {'龙头': 1, '巿': 1, '弱项': 1},
#  '的龙头': {'期刊': 1},
#  '龙头期刊': {'更是': 1},
#  '期刊更是': {'从': 1},
#  '更是从': {'一本': 1},
#  '从一本': {'传统': 1},
#  '一本传统': {'的': 1},
#  '传统的': {'《': 1, '情报工作': 1, '推进': 1, '情报战': 1, '战争': 1, '极权': 1, '地面': 1},
#  '的《': {'科幻世界': 1, '最后': 1, '太空': 2, '卜算子': 1, '门槛': 1, '清明上河图': 1, '星空': 2},
#  '《科幻世界': {'》': 1},
#  '科幻世界》': {'，': 1},
#  '》，': {'发展壮大': 1,
#   '疯狂': 1,
#   '那': 1,
#   '这': 1,
#   '任何': 1,
#   '对': 1,
#   '取材': 1,
#   '一种': 1,
#   '很': 1,
#   '没想到': 1,
#   '他': 1,
#   '像': 1},
#  '，发展壮大': {'成为': 1},
#  '发展壮大成为': {'涵盖': 1},
#  '成为涵盖': {'各个': 1},
#  '涵盖各个': {'读者': 1},
#  '各个读者': {'层': 1},
#  '读者层': {'的': 1},
#  '层的': {'系列': 1},
#  '的系列': {'刊物': 1},
#  '系列刊物': {'。': 1},
#  '刊物。': {'与此同时': 1},
#  '。与此同时': {'，': 9},
#  '与此同时，': {'科幻': 1,
#   '在': 3,
#   '太空': 1,
#   '程心': 2,
#   '卫队长': 1,
#   '物质': 1,
#   '一片': 1,
#   '她': 1},
#  '，科幻': {'文学': 1},
#  '的巿': {'场': 1},
#  '巿场': {'环境': 1},
#  '场环境': {'也': 1},
#  '环境也': {'有': 1},
#  '也有': {'了': 1,
#   '好': 1,
#   '话': 1,
#   '过': 2,
#   '可能': 3,
#   '清晰度': 1,
#   'AA': 1,
#   '几十米': 1,
#   '共同之处': 1,
#   '一套': 1,
#   '达': 1,
#   '一定': 1,
#   '六': 1,
#   '飞船': 1,
#   '的': 1,
#   '无数': 1,
#   '巨大': 1,
#   '一行': 1,
#   '这种': 2,
#   '几条': 1,
#   '两个': 1,
#   '幸福': 1,
#   '许多': 2,
#   '体积': 1,
#   '一部分': 2,
#   '勇气': 1,
#   '一些': 1,
#   '平行': 1,
#   '比': 1,
#   '少数': 1,
#   '一个': 1,
#   '部分': 1,
#   '类似': 1,
#   '一块': 1,
#   '中微子': 1},
#  '有了': {'改善': 1,
#   '属于': 1,
#   '实际意义': 1,
#   '一种': 2,
#   '和': 1,
#   '震撼': 2,
#   '一定': 1,
#   '一颗': 1,
#   '第一批': 1,
#   '些': 3,
#   '初步': 1,
#   '最后': 1,
#   '眸子': 1,
#   '神': 1,
#   '准确': 2,
#   '大': 1,
#   '很': 1,
#   '全新': 2,
#   '上下': 2,
#   '奇特': 1,
#   '故事': 1,
#   '联系': 1,
#   '意义': 1,
#   '站': 1,
#   '漫天': 1,
#   '质能': 1,
#   '一百': 1,
#   '恐惧': 1,
#   '诚意': 1,
#   '一个': 4,
#   '“': 1,
#   '一些': 1,
#   '泪光': 1,
#   '很大': 1,
#   '散射': 1,
#   '微妙': 1},
#  '了改善': {'，': 1},
#  '改善，': {'省会': 1},
#  '，省会': {'级': 1},
#  '省会级': {'城市': 1},
#  '级城市': {'的': 1},
#  '城市的': {'大型': 1,
#   '危局': 1,
#   '末日': 1,
#   '光雾': 1,
#   '灯海': 3,
#   '灯光': 1,
#   '巨树': 2,
#   '澳大利亚': 1,
#   '地下': 1,
#   '下水道': 1,
#   '照片': 1,
#   '建筑': 1,
#   '规模': 1,
#   '伤痕': 1,
#   '原材料': 1,
#   '巨': 1,
#   '唯一': 1,
#   '一面': 1,
#   '某处': 1,
#   '太空': 1,
#   '旋转': 1,
#   '水体': 1,
#   '一条': 1,
#   '构型': 1,
#   '边缘': 1,
#   '全景': 1,
#   '中轴线': 2,
#   '其余部分': 1,
#   '空间': 1,
#   '一个': 1,
#   '其他': 1,
#   '一张': 1,
#   '所有': 1,
#   '总体布局': 1},
#  '的大型': {'书店': 1, '工程项目': 1, '部件': 1, '存储': 1, '黑洞': 1, '太空城': 2},
#  '大型书店': {'里': 1},
#  '书店里': {'终于': 1},
#  '里终于': {'有': 1},
#  '终于有': {'了': 2, '机会': 1},
#  '了属于': {'枓': 1},
#  '属于枓': {'幻': 1},
#  '枓幻': {'的': 1},
#  '幻的': {'领地': 1},
#  '的领地': {'。': 1},
#  '领地。': {'仍然': 1},
#  '。仍然': {'有人': 1, '看不到': 1},
#  '仍然有人': {'经常': 1},
#  '有人经常': {'问及': 1},
#  '经常问及': {'中国': 1},
#  '问及中国': {'科幻': 1},
#  '科幻与': {'美国': 1},
#  '与美国': {'科幻': 2},
#  '美国科幻': {'的': 2, '从朗': 1},
#  '科幻的': {'差距': 2, '全方位': 1},
#  '的差距': {'，': 2, '。': 1},
#  '差距，': {'但': 1, '实际上': 1},
#  '，但': {'现在': 30,
#   '宇宙': 2,
#   '等到': 1,
#   '他': 27,
#   '另': 1,
#   '看得出': 1,
#   '君士坦丁': 1,
#   '肯定': 8,
#   '知道': 2,
#   '绝不能': 1,
#   '并': 8,
#   '妓女': 1,
#   '她': 36,
#   '上帝': 1,
#   '那些': 4,
#   '双眸': 1,
#   '周围': 1,
#   '财政': 1,
#   '还是': 16,
#   '在': 41,
#   '想到': 1,
#   '你': 4,
#   '至少': 3,
#   '能': 4,
#   '就': 3,
#   '仍': 13,
#   '没有': 28,
#   '雨滴': 1,
#   '对': 9,
#   '张': 1,
#   '一时': 2,
#   '记者': 1,
#   '哪儿': 1,
#   '回想': 1,
#   '长大': 1,
#   '不': 7,
#   '从': 10,
#   '那': 6,
#   '身体': 1,
#   '这个': 8,
#   '限于': 1,
#   '对方': 1,
#   '自从': 1,
#   '无话可说': 1,
#   '父母': 1,
#   '从来': 1,
#   '这': 19,
#   '困难重重': 1,
#   '被': 1,
#   '结果': 1,
#   '主要': 2,
#   '隐藏': 1,
#   '丝毫': 2,
#   '维德': 2,
#   '鉴于': 1,
#   '没想到': 1,
#   '都': 10,
#   '他们': 16,
#   '野蛮': 1,
#   '推进': 1,
#   '做': 1,
#   'PIA': 2,
#   '直接': 1,
#   '当': 5,
#   '也': 20,
#   '对于': 7,
#   '同时': 2,
#   '脚步': 2,
#   '不能': 3,
#   '即使': 5,
#   '强度': 1,
#   '再': 1,
#   '当天': 1,
#   '我': 14,
#   '这项': 1,
#   '必然': 1,
#   '放射': 1,
#   '一旦': 2,
#   '上面': 2,
#   '意识': 1,
#   '测试': 1,
#   '要': 6,
#   '不会': 3,
#   '没': 4,
#   '显得': 1,
#   '又': 2,
#   '寒气': 1,
#   '不是': 2,
#   '距': 1,
#   '“': 5,
#   '发出': 2,
#   '声音': 2,
#   '你们': 2,
#   '由于': 13,
#   '三千五百': 1,
#   '这三人': 1,
#   '地球': 2,
#   '后者': 1,
#   '技术': 1,
#   '按照': 4,
#   '却': 8,
#   '随着': 3,
#   '说': 1,
#   '这次': 1,
#   '已经': 3,
#   '挡': 1,
#   '全身': 1,
#   '动作': 1,
#   '最终': 2,
#   '人们': 7,
#   '与': 12,
#   '仅仅': 2,
#   '如果': 8,
#   '想想': 1,
#   '随之而来': 1,
#   '真正': 1,
#   '似乎': 1,
#   '那个': 1,
#   '无论': 1,
#   '母性': 1,
#   '只有': 2,
#   '只要': 2,
#   '两舰': 1,
#   '智子': 4,
#   '同行': 1,
#   '在精神上': 1,
#   '心理': 1,
#   '立刻': 3,
#   '弓弦': 1,
#   '旋即': 1,
#   '看上去': 2,
#   '实在': 1,
#   '四周': 1,
#   '这些': 2,
#   '极': 1,
#   '另一类': 1,
#   '要求': 1,
#   '没人': 1,
#   '若': 1,
#   '不乱': 1,
#   'AA': 3,
#   '烟尘': 1,
#   '不得不': 1,
#   '执剑人': 1,
#   '它们': 8,
#   '其': 6,
#   '可以': 6,
#   '只是': 3,
#   '老人': 1,
#   '很快': 11,
#   '看到': 2,
#   '战舰': 1,
#   '火星': 1,
#   '放到': 1,
#   '像': 2,
#   '弗雷斯': 1,
#   '很': 6,
#   '就是': 2,
#   '透出': 1,
#   '举止': 1,
#   '直到现在': 1,
#   '没带': 1,
#   '自然': 1,
#   '不知': 1,
#   '世界': 1,
#   '除了': 1,
#   '因': 1,
#   '怎么': 1,
#   '再次': 1,
#   '…': 2,
#   '两舰间': 1,
#   '太空': 3,
#   '那天': 1,
#   '亨特': 1,
#   '警报': 1,
#   '应该': 1,
#   '数据': 1,
#   '累积': 1,
#   '表面': 1,
#   '脸上': 1,
#   '杀伤力': 1,
#   '刚刚': 1,
#   '希望': 1,
#   '命运': 1,
#   '最好': 2,
#   '频谱': 1,
#   '一切': 1,
#   '任何': 1,
#   '必须': 1,
#   '从未': 2,
#   '有': 2,
#   '明显': 1,
#   '应答': 1,
#   '经过': 2,
#   '浸透': 1,
#   '移民': 1,
#   '后来': 5,
#   '保证': 1,
#   '学术界': 1,
#   '认为': 1,
#   '确实': 1,
#   '几乎': 1,
#   '变得': 1,
#   '通话': 1,
#   '人类': 4,
#   '一直': 1,
#   '向': 1,
#   '灾难': 1,
#   '再也': 2,
#   '查阅': 1,
#   '需要': 1,
#   '只能': 3,
#   '公众': 1,
#   '这种': 3,
#   '所有': 2,
#   '最后': 2,
#   '看来': 1,
#   '考虑': 1,
#   '窄小': 1,
#   '房间': 1,
#   '这时': 2,
#   '运载': 1,
#   '大厅': 1,
#   '显然': 1,
#   '参谋长': 1,
#   '比': 3,
#   '看不到': 1,
#   '刚才': 1,
#   '女孩子': 1,
#   '渐渐': 2,
#   '两个': 1,
#   '各国': 1,
#   '作为': 1,
#   '我们': 7,
#   '从小': 1,
#   '锐利': 1,
#   '看不出': 1,
#   '画面': 1,
#   '表情': 1,
#   '它': 4,
#   '奇怪的是': 1,
#   '不管怎样': 1,
#   '发现': 2,
#   '老': 1,
#   '更': 1,
#   '尽管': 1,
#   '公主': 4,
#   '连': 1,
#   '比冰沙': 1,
#   '巨人': 1,
#   '香皂': 1,
#   '一': 1,
#   '留': 1,
#   '还': 3,
#   '无数': 1,
#   '经验丰富': 1,
#   '，': 2,
#   '深水': 1,
#   '卫队长': 1,
#   '模糊性': 1,
#   '哪个': 1,
#   '不同': 1,
#   '进一步': 1,
#   '故事': 1,
#   '船': 1,
#   '打定主意': 1,
#   '空间': 1,
#   '很少': 1,
#   '没能': 1,
#   '受到': 1,
#   '文学': 1,
#   '观察者': 1,
#   '实现': 1,
#   '具体内容': 1,
#   '为了': 1,
#   '机舱': 1,
#   '无比': 1,
#   '却是': 1,
#   '航程': 1,
#   '给': 1,
#   '只': 2,
#   '这里': 1,
#   '图像': 1,
#   '形状': 1,
#   '谁': 1,
#   '迈向': 1,
#   '太阳系': 1,
#   '进入': 1,
#   '公司': 1,
#   '能够': 2,
#   '正像': 1,
#   '太': 2,
#   '岁月': 1,
#   '广告': 1,
#   '窗口': 1,
#   '体积': 2,
#   '数量': 1,
#   '里面': 1,
#   '最大': 1,
#   '这样': 2,
#   '几年': 1,
#   '内部空间': 1,
#   '风格各异': 1,
#   '背': 1,
#   '已': 1,
#   '最终目标': 1,
#   '装配': 1,
#   '总': 1,
#   '弹头': 1,
#   '子弹': 1,
#   '终于': 1,
#   '早已': 1,
#   '放眼望去': 1,
#   '据说': 1,
#   '先前': 1,
#   '歌者': 1,
#   '低温': 1,
#   '背景': 1,
#   '发射': 1,
#   '有效载荷': 1,
#   '理论物理学': 1,
#   '直觉': 2,
#   '要说': 1,
#   '车体': 1,
#   '无济于事': 1,
#   '加速': 1,
#   '超重': 1,
#   '飞船': 2,
#   '分形': 1,
#   '合作': 1,
#   '剩下': 1,
#   '木星': 1,
#   '说话': 1,
#   '随之': 1,
#   '姿态': 1,
#   '毫无疑问': 1,
#   '等离子体': 1,
#   '变暗': 1,
#   '质地': 1,
#   '面罩': 1,
#   '整体': 1,
#   '密密的': 1,
#   '星体': 1,
#   '超越': 1,
#   '这点': 1,
#   '时间': 1,
#   '总体': 1,
#   '向后看': 1,
#   '以亚': 1,
#   '天空': 1,
#   '大气压': 1,
#   '面积': 1,
#   '三维': 1,
#   '听到': 1,
#   '为': 1,
#   '目前为止': 1,
#   '仍然': 2,
#   '扰动': 1,
#   '太空服': 1,
#   '真的': 1,
#   '完成': 1,
#   '氧气': 1,
#   '头盔': 1,
#   '什么': 1,
#   '岩石': 1,
#   '移动': 1,
#   '抬腿': 1,
#   '完全': 1,
#   '走': 1,
#   '让': 1,
#   '接收': 1},
#  '但现在': {'的': 3,
#   '，': 20,
#   '看来': 1,
#   '这个': 1,
#   '她': 2,
#   '他': 2,
#   '艾克': 1,
#   '什么': 2,
#   '全是': 1,
#   '这些': 1,
#   '地面': 1,
#   '视野': 1,
#   '没有': 1,
#   '它': 1,
#   '感觉': 1,
#   '我': 1,
#   '“': 1,
#   '这里': 1,
#   '程心': 1,
#   '出现': 1,
#   '双方': 1},
#  '现在的': {'答案': 1,
#   '地球': 2,
#   '大气': 1,
#   '精神状态': 1,
#   '问题': 3,
#   '宇航': 1,
#   '思想': 1,
#   '十分之一': 1,
#   '病况': 1,
#   '大气层': 1,
#   '枪': 1,
#   '希望': 1,
#   '公众': 1,
#   '一切': 1,
#   '情况': 1,
#   '事情': 1,
#   '感觉': 1,
#   '关键问题': 1,
#   '世界': 1,
#   '云': 1,
#   '生活': 2,
#   '海风': 1,
#   '万分之一': 1,
#   '太空': 1,
#   '三体': 1,
#   '位置': 1,
#   '做法': 1,
#   '罗辑': 1,
#   '自己': 1,
#   '编号': 1,
#   '太阳系': 1,
#   '每秒': 1,
#   '太空服': 1,
#   '光速': 1,
#   '年代': 1},
#  '的答案': {'已': 1, '：': 1, '，': 1, '肯定': 1, '。': 1},
#  '答案已': {'与': 1},
#  '已与': {'十年': 1, '正常人': 1, '泡沫': 1, '程心': 1},
#  '与十年': {'前': 1},
#  '十年前': {'不同': 1, '一帮': 1, '，': 1},
#  '前不同': {'。': 1},
#  '不同。': {'在': 1, '它': 1, '首先': 1, '曾': 1, '她': 1, '旁边': 1, '好像': 1},
#  '。在': {'很多': 1,
#   '《': 2,
#   '我们': 2,
#   '一个': 5,
#   '整个': 4,
#   '接受': 1,
#   '城市': 1,
#   '两排': 1,
#   '塔': 1,
#   '一天': 1,
#   '电脑': 2,
#   '危机': 1,
#   '这种': 4,
#   '进行': 1,
#   '他': 4,
#   '极其': 1,
#   '办公室': 1,
#   '汇报会': 1,
#   '人类': 2,
#   '以前': 2,
#   '这光灿': 1,
#   '那次': 1,
#   '程心': 4,
#   '对': 1,
#   '听众席': 1,
#   '脑外科': 1,
#   '最初': 1,
#   '上校': 1,
#   '离开': 1,
#   '过去': 3,
#   '当年': 1,
#   '威慑': 8,
#   '传统': 1,
#   '以后': 3,
#   '她': 3,
#   '双方': 2,
#   '追击': 1,
#   '半个世纪': 5,
#   '水滴': 2,
#   '全体': 1,
#   '一百多名': 1,
#   '真正': 1,
#   '最': 1,
#   '这方面': 1,
#   '飞车': 1,
#   '接近': 2,
#   '扑面而来': 1,
#   '引力波': 1,
#   '三体': 3,
#   '史称': 1,
#   '一年': 1,
#   '澳大利亚': 1,
#   '移民': 3,
#   '移民区': 1,
#   '弗雷斯': 1,
#   '一片': 1,
#   '那': 7,
#   '这里': 3,
#   '这些': 3,
#   '门廊': 1,
#   '通过': 2,
#   '一间': 1,
#   '空中': 1,
#   '农业': 1,
#   '这': 11,
#   '这个': 16,
#   '操作': 1,
#   '头': 1,
#   '诱使': 1,
#   '几十年': 1,
#   '那个': 2,
#   '全舰': 1,
#   '高倍': 1,
#   '穿梭机': 1,
#   '刚才': 1,
#   '“': 5,
#   '奧': 1,
#   '飞船': 6,
#   '他们': 2,
#   '三维': 6,
#   '莫沃': 1,
#   '三维空间': 1,
#   '四维': 1,
#   '四维空间': 2,
#   '接下来': 4,
#   '出发': 1,
#   '来自': 1,
#   '探险': 1,
#   '倒': 1,
#   '减速': 1,
#   '它': 1,
#   '那样': 1,
#   '广播': 1,
#   '悬挂': 1,
#   '三天': 1,
#   '已经': 1,
#   '死亡': 1,
#   '刚刚': 1,
#   '两次': 1,
#   '地球': 3,
#   '得知': 1,
#   '别墅': 1,
#   '历史学家': 1,
#   '木星': 1,
#   '导轨': 1,
#   '随后': 3,
#   '两个': 1,
#   '四环': 1,
#   '即将': 1,
#   '不远处': 1,
#   '麦田': 3,
#   '阶梯': 1,
#   '几': 1,
#   '智子': 2,
#   '返航': 1,
#   '第四遍': 1,
#   '透明': 1,
#   '屏蔽': 1,
#   '大部分': 1,
#   '讲述': 1,
#   '十几里': 1,
#   '宫殿': 1,
#   '把': 1,
#   '天亮': 1,
#   '太阳': 3,
#   '一次': 1,
#   '来时': 1,
#   '石阶': 1,
#   '打击': 4,
#   '规划': 1,
#   'IDC': 1,
#   '一家': 1,
#   '香皂': 1,
#   '盟洗': 1,
#   '众多': 1,
#   '此例': 1,
#   '被': 1,
#   '公元': 1,
#   '光速': 2,
#   '潜意识': 1,
#   '树顶': 1,
#   '前方': 1,
#   '她们': 1,
#   '滚滚': 1,
#   '世界各地': 1,
#   '太空': 5,
#   '望远镜': 1,
#   '引力': 1,
#   '星云': 1,
#   '星系': 1,
#   '视野': 1,
#   '拉格朗': 1,
#   '从': 1,
#   '返回': 1,
#   '另一侧': 2,
#   '走廊': 1,
#   '旋转': 1,
#   '另外': 1,
#   '艇': 1,
#   '这座': 1,
#   '球形': 1,
#   '掩体': 3,
#   '需要': 1,
#   '到达': 1,
#   '介质': 1,
#   '产生': 1,
#   '托马斯': 1,
#   '星': 1,
#   '遥远': 1,
#   '辐条': 1,
#   '废墟': 1,
#   '与': 2,
#   '大厅': 1,
#   '最后': 1,
#   '太阳系': 2,
#   '星环': 1,
#   '岛上': 1,
#   '窗外': 1,
#   '外星': 1,
#   '几天': 1,
#   '理智': 1,
#   '外观': 1,
#   '纸条': 1,
#   '这场': 1,
#   '两千': 1,
#   '另': 1,
#   '二维': 2,
#   '这幅': 1,
#   '极度': 1,
#   '方碑': 1,
#   '那时': 1,
#   '冥王星': 2,
#   '打开': 1,
#   '两颗': 1,
#   '来': 1,
#   '升起': 1,
#   '这张': 1,
#   '画面': 1,
#   '那些': 1,
#   '五十个': 1,
#   '那里': 1,
#   '之前': 2,
#   '雪': 1,
#   '每': 1,
#   '技术开发': 1,
#   '曲率': 2,
#   '航迹': 1,
#   '宇宙': 1,
#   '研究': 1,
#   '监视系统': 1,
#   '明亮': 1,
#   '旅行': 1,
#   '肉体上': 1,
#   '这仅': 1,
#   '登上': 1,
#   '两舰': 1,
#   '战争': 1,
#   '狭窄': 2,
#   '戴': 1,
#   '冬眠': 1,
#   '监视': 1,
#   '这片': 1,
#   '等待': 1,
#   'DX3906': 1,
#   '这样': 1,
#   '千万年': 1,
#   '地面': 1,
#   '蓝色': 1,
#   '土地': 1,
#   '渐渐': 1,
#   '地平线': 1,
#   '房子': 1,
#   '小': 2,
#   '新': 1,
#   '银河系': 1,
#   '永远': 1,
#   '彩虹': 1,
#   '一小块': 1},
#  '在很多': {'作品': 1},
#  '很多作品': {'上': 1},
#  '作品上': {'（': 1},
#  '上（': {'它们': 1},
#  '（它们': {'不再': 1},
#  '它们不再': {'是': 1},
#  '不再是': {'那种': 1,
#   '英雄': 1,
#   '对': 1,
#   '绝对': 1,
#   '一个': 2,
#   '一': 1,
#   '对方': 1,
#   '巨人': 1,
#   '真实': 1,
#   '有': 1,
#   '黑色': 1,
#   '零': 1,
#   '稳定': 1},
#  '是那种': {'毫无': 1, '与': 1, '阳光': 1, '光洁': 1, '程心': 1, '有': 1, '若有所思': 1},
#  '那种毫无': {'文学': 1},
#  '毫无文学': {'技巧': 1},
#  '文学技巧': {'与': 1},
#  '技巧与': {'色彩': 1},
#  '与色彩': {'、': 1},
#  '色彩、': {'想象力': 1},
#  '、想象力': {'拘谨': 1},
#  '想象力拘谨': {'的': 1},
#  '拘谨的': {'幼稚': 1},
#  '的幼稚': {'故事': 1, '症': 1, '，': 1},
#  '幼稚故事': {'）': 1},
#  '故事）': {'，': 1},
#  '），': {'这种': 1,
#   '大阳系': 1,
#   '探测': 1,
#   '参加': 1,
#   '为了': 1,
#   '因而': 1,
#   '在': 3,
#   '这是': 1,
#   '而是': 1,
#   '他们': 1,
#   '但': 1,
#   '平均': 1,
#   '看上去': 1,
#   '总体': 1,
#   '有': 1,
#   '大': 1},
#  '，这种': {'比较': 1,
#   '斗篷': 1,
#   '改变': 2,
#   '情况': 4,
#   '古典': 1,
#   '信心': 1,
#   '行为': 2,
#   '感觉': 2,
#   '千扰': 1,
#   '事': 2,
#   '提升': 1,
#   '力场': 1,
#   '纵深': 1,
#   '四维': 1,
#   '可能性': 1,
#   '光速': 1,
#   '群体': 1,
#   '平静': 1,
#   '技术': 1,
#   '爱': 1,
#   '凝视': 1,
#   '转换': 1,
#   '鱼': 1,
#   '香皂': 1,
#   '机器': 2,
#   '观测': 2,
#   '拒绝': 1,
#   '冲突': 1,
#   '巨大': 1,
#   '辐射': 1,
#   '遗憾': 1,
#   '前景': 1,
#   '绝望': 1,
#   '引力': 1,
#   '线圈': 1,
#   '能': 1,
#   '引力波': 1,
#   '判断': 1,
#   '封装': 1,
#   '事情': 1,
#   '规律': 1,
#   '色彩': 1,
#   '拥抱': 1,
#   '痛哭': 1,
#   '文字': 1},
#  '这种比较': {'已经': 1},
#  '比较已经': {'变成': 1},
#  '已经变成': {'了': 6, '一艘': 1, '一个': 1, '一幅': 1, '紫星': 1, '一轮': 1, '真空': 1},
#  '变成了': {'人家': 1,
#   '齐': 1,
#   '地狱': 1,
#   '阶梯': 1,
#   '一艘': 1,
#   '一个': 5,
#   '一颗': 2,
#   '虚空': 1,
#   '一间': 1,
#   '一具': 1,
#   '红色': 2,
#   '宇宙飞船': 1,
#   '一枚': 1,
#   '长长的': 1,
#   '比': 1,
#   '拯救': 1,
#   '死寂': 1,
#   '魔鬼': 1,
#   ' ': 1,
#   '一块': 1,
#   '直线': 1,
#   '孩子': 1,
#   '一根': 1,
#   '暗': 1,
#   '低': 2,
#   '神': 1,
#   '不见': 1,
#   '坠落': 1,
#   '一部': 1,
#   '挂': 1,
#   '死': 1,
#   '无': 1,
#   '蓝色': 1,
#   '一副': 1,
#   '纯': 2,
#   '宣传': 1,
#   '类似': 1,
#   '漆黑': 1,
#   '文物': 1,
#   '火葬场': 1,
#   '光芒四射': 1,
#   '柔和': 1,
#   '银色': 1,
#   '一潭死水': 1,
#   '坟墓': 1,
#   '漂亮': 1,
#   '椭圆': 2,
#   '月亮': 1,
#   '最': 1,
#   '两个': 1,
#   '虚无': 1,
#   '黑白': 1,
#   '死神': 1,
#   '发光': 1,
#   '这个': 1,
#   '紫色': 1,
#   '表音': 1},
#  '了人家': {'的': 1},
#  '人家的': {'牛排': 1},
#  '的牛排': {'之': 1},
#  '牛排之': {'于': 1},
#  '之于': {'我们': 1},
#  '于我们': {'的': 1},
#  '我们的': {'土豆': 1,
#   '科幻': 1,
#   '图书': 1,
#   '中国': 1,
#   '作家': 1,
#   '生活': 1,
#   '专业': 1,
#   '天使': 1,
#   '航线': 1,
#   '世界': 6,
#   '人格': 1,
#   '引力波': 1,
#   '母星': 1,
#   '三维': 1,
#   '飞船': 1,
#   '一切': 1,
#   '有关': 1,
#   '比喻': 1,
#   '价值观': 1,
#   '善意': 1,
#   '血肉': 1,
#   '星星': 7,
#   '注意力': 1,
#   '小学': 1,
#   '行踪': 1,
#   '。': 1,
#   '视野': 1,
#   '发射': 1,
#   '身份': 1,
#   '理想': 1,
#   '事业': 1,
#   '力量': 1,
#   '武器': 1,
#   '作战': 1,
#   '要求': 1,
#   '子孙': 1,
#   '同行': 1,
#   '正式': 1,
#   '海洋': 1,
#   '海': 1,
#   '猜测': 1,
#   '那个': 1,
#   '宇宙': 1,
#   '大': 1,
#   '一份': 1},
#  '的土豆': {'牛肉': 1, '形': 1},
#  '土豆牛肉': {'。': 1},
#  '牛肉。': {'差距': 1},
#  '。差距': {'是': 1},
#  '差距是': {'明显': 1},
#  '是明显': {'的': 2},
#  '明显的': {'一': 1,
#   '痕迹': 1,
#   '智慧': 2,
#   '偏心眼': 1,
#   '血迹': 1,
#   '病容': 1,
#   '高温': 1,
#   '恐惧': 1,
#   '特征': 2,
#   '共同点': 1,
#   '神迹': 1,
#   '感觉': 1,
#   '落差': 1,
#   '隐喻': 2,
#   '也': 1,
#   '原因': 1,
#   '陆战': 1,
#   '敬畏': 1,
#   '自豪': 1,
#   '透视': 1,
#   '生命': 1,
#   '威慑': 1,
#   '不同': 1,
#   '变化': 1},
#  '的一': {'更': 1, '闪念': 1, '百吨': 1, '大片': 2, '滴滴': 1, '长条': 1},
#  '一更': {'准确': 1},
#  '更准确': {'地说': 1, '的': 2},
#  '准确地说': {'，': 1},
#  '地说，': {'应该': 1,
#   '那种': 1,
#   '他': 2,
#   '她': 1,
#   '没有': 1,
#   '一反': 1,
#   '“': 4,
#   '这座': 1,
#   '用': 1,
#   '智子': 1,
#   '关一帆': 1,
#   '然后': 1},
#  '，应该': {'是': 7,
#   '知道': 1,
#   '会': 1,
#   '够': 1,
#   '能': 2,
#   '不': 1,
#   '还有': 1,
#   '制作': 1,
#   '不会': 1,
#   '已经': 2,
#   '没错': 1,
#   '不是': 1,
#   '没有': 1,
#   '可以': 1},
#  '应该是': {'“': 1,
#   '什么样': 1,
#   '我们': 1,
#   '未来': 1,
#   '这样': 1,
#   '她': 1,
#   '五年': 1,
#   '极其': 1,
#   '在': 1,
#   '有': 1,
#   '站': 1,
#   '什么': 1,
#   '这': 1,
#   '，': 2,
#   '无害': 1,
#   '惊心动魄': 1,
#   '圆形': 1,
#   '太空服': 1,
#   '安全': 1,
#   '星星': 2,
#   '重要': 1},
#  '是“': {'差别': 1,
#   '精骛': 1,
#   '绿色': 1,
#   '军事': 1,
#   '卡西尼': 1,
#   '青铜时代': 1,
#   '量子': 1,
#   '人': 1,
#   '地球': 1,
#   '万有引力': 3,
#   '蓝色': 6,
#   '透过': 1,
#   '干净': 1,
#   '木星': 1,
#   '星环': 3},
#  '“差别': {'“': 1},
#  '差别“': {'一': 1},
#  '“一': {'却': 1, '”': 2},
#  '一却': {'已经': 1},
#  '却已经': {'无法': 1, '开始': 1, '死': 1},
#  '已经无法': {'再': 1, '阻拦': 1, '联系': 1},
#  '无法再': {'为': 1, '传出': 1},
#  '再为': {'它们': 1},
#  '为它们': {'排个': 1, '让开': 1},
#  '它们排个': {'名次': 1},
#  '排个名次': {'。': 1},
#  '名次。': {'口味': 1},
#  '。口味': {'问题': 1},
#  '口味问题': {'有': 1},
#  '问题有': {'了': 1},
#  '了实际意义': {'，': 1},
#  '实际意义，': {'这': 1},
#  '，这': {'正是': 2,
#   '也': 19,
#   '本身': 2,
#   '难度': 1,
#   '故事': 1,
#   '只不过': 1,
#   '难道': 2,
#   '就让': 1,
#   '灰尘': 1,
#   '震撼': 1,
#   '只': 1,
#   '是': 28,
#   '你': 2,
#   '一次': 8,
#   '声浪': 3,
#   '引起': 2,
#   '生活': 1,
#   '让': 3,
#   '感觉': 2,
#   '中间': 5,
#   '在': 7,
#   '可能': 7,
#   '一点': 3,
#   '并': 3,
#   '里面': 2,
#   '本来': 1,
#   '就': 21,
#   '两个': 5,
#   '一度': 1,
#   '两种': 2,
#   '不是': 10,
#   '就是': 30,
#   '段': 1,
#   '有点': 1,
#   '简短': 1,
#   '与': 3,
#   '使得': 12,
#   '仍然': 1,
#   '没什么': 1,
#   '完全': 2,
#   '类': 1,
#   '多少': 2,
#   '对': 4,
#   '一切': 6,
#   '只有': 1,
#   '被': 1,
#   '不过': 2,
#   '巨量': 1,
#   '真的': 1,
#   '堵墙': 1,
#   '人': 2,
#   '动作': 1,
#   '沉重': 1,
#   '目光': 2,
#   '35': 1,
#   '基因': 1,
#   '说明': 1,
#   '段距离': 1,
#   '一直': 2,
#   '一定': 1,
#   '已经': 3,
#   '无疑': 1,
#   '一大': 1,
#   '三个': 2,
#   '总行': 1,
#   '黑暗': 1,
#   '仍': 1,
#   '根本': 1,
#   '…': 2,
#   '两天': 1,
#   '将': 4,
#   '几十只': 1,
#   '振动': 1,
#   '声音': 3,
#   '张纸': 1,
#   '东西': 7,
#   '一方面': 1,
#   '正好': 1,
#   '一部分': 1,
#   '出乎': 1,
#   '段时间': 3,
#   '两颗': 1,
#   '敬畏': 1,
#   '断绝': 1,
#   '意味着': 4,
#   '半个世纪': 1,
#   '其中': 1,
#   '人类': 1,
#   '只是': 3,
#   '很': 3,
#   '是不是': 2,
#   '一群': 1,
#   '把': 1,
#   '空旷': 1,
#   '更': 1,
#   '对于': 1,
#   '张膜': 1,
#   '意义': 1,
#   '期间': 2,
#   '笑容': 1,
#   '简直': 1,
#   '绝对': 1,
#   '毕竟': 1,
#   '似乎': 2,
#   '六十多年': 1,
#   '也许': 1,
#   '就要': 3,
#   '只能': 1,
#   '一小': 1,
#   '一带': 2,
#   '条': 4,
#   '都': 1,
#   '又': 2,
#   '有时': 1,
#   '大脑': 1,
#   '一代': 1,
#   '面': 1,
#   '应该': 1,
#   '微笑': 1,
#   '两只': 1,
#   '是从': 1,
#   '导致': 1,
#   '和': 1,
#   '星体': 1,
#   '最后': 1,
#   '五十多年': 1,
#   '引力': 1,
#   '真是': 1,
#   '仅仅': 1,
#   '显然': 1,
#   '四个': 1,
#   '重力': 1,
#   '名字': 1,
#   '可以': 1,
#   '一刻': 2,
#   '肯定': 1,
#   '好像': 1,
#   '世界': 1,
#   '数据': 1,
#   '所有': 1,
#   '过程': 1,
#   '几乎': 1},
#  '这正是': {'我们': 2, '五号': 1, '黎明前': 1, '我': 1},
#  '正是我们': {'的': 1, '这个': 1, '要': 1},
#  '科幻走向': {'成熟': 1},
#  '走向成熟': {'的': 1},
#  '成熟的': {'标志': 2, '。': 1, '麦田': 1},
#  '的标志': {'。': 3, '，': 1},
#  '标志。': {'与': 1, '智子': 1, '安全': 1},
#  '。与': {'美国': 1,
#   '他': 1,
#   '以前': 3,
#   '云': 1,
#   '舰': 2,
#   '她': 1,
#   '其他': 4,
#   '智子': 1,
#   '威慑': 1,
#   '一般': 1,
#   '两舰': 1,
#   '球形': 1,
#   '前面': 1,
#   '第一轮': 1,
#   '物质': 1,
#   '大多数': 1,
#   '永远': 1,
#   '人类': 1,
#   '治安': 1,
#   '他们': 1,
#   '这些': 1,
#   '伞': 1,
#   '程心': 2,
#   '普通人': 1,
#   '前': 1,
#   '公元': 2,
#   '亚洲一号': 1,
#   '光速': 1,
#   '下方': 1,
#   '导师': 1,
#   '‘': 1,
#   '工程图纸': 1,
#   '它': 1,
#   '想象': 1,
#   '后者': 1,
#   '地球': 1,
#   '“': 1,
#   '表音文字': 1,
#   '大': 1},
#  '，实际上': {'是': 1, '就是': 1},
#  '实际上是': {'巿': 1, '在': 1, '一条': 1, '跳跃': 1},
#  '是巿': {'场化': 1},
#  '巿场化': {'程度': 1, '的': 1},
#  '场化程度': {'的': 1},
#  '程度的': {'差距': 1, '成熟': 1},
#  '差距。': {'美国': 1},
#  '。美国': {'科幻': 1},
#  '科幻从朗': {'刊到': 1},
#  '从朗刊到': {'图书': 1},
#  '刊到图书': {'到': 1},
#  '图书到': {'影视': 1},
#  '到影视': {'再': 1},
#  '影视再': {'到': 1},
#  '再到': {'游戏': 1, '威慑': 1, '后来': 1, '六十个': 1},
#  '到游戏': {'和': 1},
#  '游戏和': {'玩具': 1},
#  '和玩具': {'，': 1},
#  '玩具，': {'已经': 1, '只有': 1},
#  '，已经': {'形成': 1,
#   '开始': 1,
#   '因': 1,
#   '使': 1,
#   '不': 1,
#   '由': 1,
#   '穿过': 1,
#   '累积': 1,
#   '被击成': 1,
#   '接近': 2,
#   '没有': 1,
#   '七十八岁': 1,
#   '死去': 1,
#   '成': 1,
#   '在': 1,
#   '离开': 1,
#   '连续': 1,
#   '很': 1,
#   '冷却': 1,
#   '能够': 1,
#   '很难': 1,
#   '保存': 1,
#   '是': 1,
#   '明显': 1,
#   '分辨': 1,
#   '远离': 1,
#   '高出': 1,
#   '证明': 1,
#   '有人': 1,
#   '不用': 1,
#   '不是': 1,
#   '广播': 1,
#   '变成': 1},
#  '已经形成': {'了': 1},
#  '形成了': {'一条': 2,
#   '鲜明': 1,
#   '一股': 1,
#   '一道': 1,
#   '一根': 1,
#   '一座': 1,
#   '某种': 1,
#   '组合体': 1,
#   '一片': 2,
#   '大量': 1},
#  '了一条': {'完整': 1,
#   '有关': 1,
#   '来自': 1,
#   '渊龙': 1,
#   '长长的': 1,
#   '黑白相间': 1,
#   '流动': 1,
#   '。': 1,
#   '失重': 1,
#   '信息': 2,
#   '简短': 1},
#  '一条完整': {'的': 1},
#  '完整的': {'产业链': 1,
#   '尖塔': 1,
#   '人': 1,
#   '他': 1,
#   '学科': 1,
#   '世界': 1,
#   '本人': 1,
#   '词': 1,
#   '球体': 1,
#   '生命体': 1},
#  '的产业链': {'，': 1},
#  '产业链，': {'动力': 1},
#  '，动力': {'十足': 1},
#  '动力十足': {'；': 1},
#  '十足；': {'而': 1},
#  '；而': {'我们': 1,
#   '《': 1,
#   '在': 1,
#   '大国': 1,
#   '大家': 1,
#   '那些': 1,
#   '回到': 1,
#   '维德': 1,
#   '就算': 1,
#   '人类': 1,
#   '现在': 1,
#   '‘': 1,
#   '拥有': 1,
#   '她': 2,
#   '二维': 1,
#   '两颗': 1},
#  '而我们': {'的': 1},
#  '的图书': {'出版': 1},
#  '图书出版': {'却': 1, '是': 1},
#  '出版却': {'仍然': 1},
#  '却仍然': {'处于': 1},
#  '仍然处于': {'这样': 1, '保密': 1},
#  '处于这样': {'一种': 1},
#  '这样一种': {'局面': 1, '武器': 1, '东西': 1},
#  '一种局面': {'：': 1},
#  '局面：': {'渎者': 1, '占': 1},
#  '：渎者': {'的': 1},
#  '渎者的': {'阅读': 1},
#  '的阅读': {'需求': 1, '。': 1, '习惯': 1},
#  '阅读需求': {'不能': 1},
#  '需求不能': {'满足': 1},
#  '不能满足': {'的': 1, '移民': 1},
#  '满足的': {'同时': 1},
#  '的同时': {'，': 6, '不断': 1, '也': 1, '造': 1},
#  '同时，': {'出版者': 1,
#   '她': 2,
#   '旁边': 1,
#   '也': 1,
#   '通向': 1,
#   '此人': 1,
#   '人': 1,
#   '球形': 1,
#   '三体': 2,
#   '中士': 1,
#   '很快': 1,
#   '飞船': 1,
#   '它们': 1,
#   '占领者': 1,
#   '各国': 1,
#   '随着': 1,
#   '他': 1,
#   '向': 1,
#   '在': 2,
#   '按三体': 1,
#   '对于': 1,
#   '从': 1,
#   '由于': 2,
#   '一艘': 1,
#   '二维': 1,
#   '还': 1,
#   '它': 1},
#  '，出版者': {'却': 1},
#  '出版者却': {'感叹': 1},
#  '却感叹': {'于': 1},
#  '感叹于': {'科幻': 1},
#  '于科幻': {'书': 1},
#  '科幻书': {'那': 1},
#  '书那': {'区区': 1},
#  '那区区': {'几干册': 1},
#  '区区几干册': {'的': 1},
#  '几干册的': {'销量': 1},
#  '的销量': {'。': 1},
#  '销量。': {'结果': 1},
#  '。结果': {'，': 1},
#  '结果，': {'我们': 2,
#   '但': 1,
#   '你们': 1,
#   '试图': 1,
#   '沙漠化': 1,
#   '通过': 1,
#   '宇宙': 1,
#   '没有': 1,
#   '这': 1},
#  '我们基本上': {'只有': 1},
#  '基本上只有': {'为': 1},
#  '只有为': {'热爱': 1},
#  '为热爱': {'而': 1},
#  '热爱而': {'创作': 1},
#  '而创作': {'的': 2},
#  '创作的': {'科幻': 2},
#  '作家，': {'鲜有': 1, '他': 1},
#  '，鲜有': {'为': 1},
#  '鲜有为': {'版税': 1},
#  '为版税': {'而': 1},
#  '版税而': {'创作': 1},
#  '作家。': {'这': 1},
#  '。这': {'不是': 3,
#   '是': 7,
#   '震动': 1,
#   '当然': 1,
#   '不': 2,
#   '人身': 1,
#   '一天': 3,
#   '两个': 1,
#   '对': 1,
#   '几年': 1,
#   '一刻': 2,
#   '一切': 4,
#   '以后': 1,
#   '很': 2,
#   '之前': 2,
#   '还是': 1,
#   '本来': 2,
#   '中间': 1,
#   '游戏': 1,
#   '一时期': 1,
#   '在': 2,
#   '突然': 1,
#   '女人': 2,
#   '剩下': 1,
#   '如果': 1,
#   '恐惧': 1,
#   '也许': 1,
#   '意味着': 1,
#   '两种': 1,
#   '四个': 1,
#   '五十四年': 1,
#   '一片': 1,
#   '确实': 2,
#   '一次': 2,
#   '一夜': 1,
#   '一年': 1,
#   '五年': 1,
#   '使得': 1,
#   '两幅': 1,
#   '死亡': 1,
#   '只是': 2,
#   '与': 2,
#   '有些': 1,
#   '六年': 2,
#   '就是': 6,
#   '一派': 1,
#   '两次': 1,
#   '巨大': 1,
#   '显然': 2,
#   '一艘': 1,
#   '绝不': 1,
#   '间': 1,
#   '孩子': 1,
#   '正是': 1,
#   '几罐': 1,
#   '把': 1,
#   '人': 2,
#   '明显': 1,
#   '午夜': 1,
#   '完全': 1,
#   '也': 5,
#   '飞蝗': 1,
#   '景象': 1,
#   '东西': 1,
#   '八个': 1,
#   '就': 1,
#   '二十六座': 1,
#   '混': 1,
#   '几乎': 1,
#   '已经': 1,
#   '一连串': 1,
#   '两艘': 2,
#   '一幕': 1,
#   '证明': 1,
#   '情景': 2,
#   '期间': 1,
#   '幅': 1,
#   '又': 1,
#   '一切都是': 1,
#   '地面': 1},
#  '这不是': {'有': 1,
#   '表现': 1,
#   '传统': 2,
#   '洲际': 1,
#   '截瘫': 1,
#   '伪造': 1,
#   '正规': 1,
#   '伞': 1,
#   '安全': 1,
#   '他们': 1,
#   '原来': 1,
#   '倒退': 1,
#   '给': 1,
#   '为': 1,
#   '天赋': 1,
#   '他': 1,
#   '博物馆': 1,
#   '陈列': 1,
#   '它们': 1,
#   '个': 1},
#  '不是有': {'责任心': 1},
#  '有责任心': {'的': 1, '有': 1},
#  '责任心的': {'出版': 1},
#  '的出版': {'人': 1},
#  '出版人': {'所': 1},
#  '人所': {'乐于': 1, '迷恋': 1, '没有': 1},
#  '所乐于': {'看到': 1},
#  '乐于看到': {'的': 1},
#  '看到的': {'现状': 1,
#   '这颗': 1,
#   '人': 1,
#   '：': 1,
#   '三体': 1,
#   '只是': 3,
#   '画': 1,
#   '。': 3,
#   '仍然': 1,
#   '只有': 1,
#   '薇': 1,
#   '是': 6,
#   '广阔': 1,
#   '空间': 1,
#   '距离': 1,
#   '“': 2,
#   '那': 1,
#   '？': 1,
#   '仍': 1,
#   '沙漠': 1,
#   '月球': 1,
#   '一切': 2,
#   '装束': 1,
#   '，': 3,
#   '不是': 1,
#   '对': 1,
#   '形状': 1,
#   '景象': 2,
#   '恒星': 1,
#   '样子': 1,
#   '也': 1,
#   '信息': 1,
#   '世界': 1,
#   '天空': 1,
#   '没有': 2,
#   '要': 1,
#   '在': 1,
#   '木星': 1,
#   '有': 2,
#   '星星': 1,
#   '吗': 1,
#   '大': 1,
#   '其中': 1,
#   '差不多': 1,
#   '银河': 1,
#   '二维': 1,
#   '其实': 1,
#   '东西': 1,
#   '这': 1,
#   '这些': 1,
#   '一样': 1,
#   '地球': 1},
#  '的现状': {'。': 1},
#  '现状。': {'科幻世界': 1},
#  '。科幻世界': {'作为': 1},
#  '科幻世界作为': {'我国': 1},
#  '作为我国': {'最有': 1},
#  '我国最有': {'影响力': 1},
#  '最有影响力': {'的': 1},
#  '影响力的': {'专业': 1},
#  '的专业': {'科幻': 1,
#   '，': 1,
#   '面': 1,
#   '前景': 1,
#   '人员': 2,
#   '时才': 1,
#   '来说': 1,
#   '经历': 1,
#   '而言': 1,
#   '。': 1,
#   '小组': 1},
#  '专业科幻': {'出版': 1},
#  '科幻出版': {'机构': 1},
#  '出版机构': {'，': 1},
#  '机构，': {'一直': 1, '这些': 1, '这点': 1, '其': 1, '但': 1, '我们': 1},
#  '，一直': {'致力于': 1,
#   '倒插门': 1,
#   '一个': 1,
#   '在': 1,
#   '没有': 2,
#   '沿着': 1,
#   '升': 1,
#   '照顾': 1,
#   '推到': 1,
#   '待': 1,
#   '通': 1,
#   '延伸': 1,
#   '向': 1,
#   '接近': 1,
#   '拄着': 1,
#   '冬眠': 1,
#   '进入': 1,
#   '退': 1},
#  '一直致力于': {'对': 1},
#  '致力于对': {'中国': 1},
#  '对中国': {'科幻': 1},
#  '的全方位': {'推动': 1},
#  '全方位推动': {'。': 1},
#  '推动。': {'科幻': 1},
#  '科幻图书': {'出版': 1},
#  '出版是': {'其中': 1},
#  '是其中': {'的': 1, '一些': 1},
#  '其中的': {'重点': 1,
#   '一位': 1,
#   '两名': 1,
#   '作为': 1,
#   '一小部分': 1,
#   '一些': 1,
#   '所有': 1,
#   '三人': 1,
#   '二维': 1,
#   '一个': 2,
#   '饕餮': 1,
#   '生存': 1,
#   '一处': 1,
#   '平凡': 1,
#   '坐标': 1,
#   '地球': 1,
#   '水分': 1,
#   '一幅': 1,
#   '一方': 1},
#  '的重点': {'之一': 1},
#  '重点之一': {'。': 1},
#  '之一。': {'中国': 1, '主任': 1, '同程心': 1, '开始': 1, '程心': 1, '但': 1, '歌者': 1},
#  '。中国': {'科幻': 1},
#  '科幻需要': {'长远': 1},
#  '需要长远': {'眼光': 1},
#  '长远眼光': {'，': 1},
#  '眼光，': {'需要': 1, '她': 1},
#  '，需要': {'一种': 1,
#   '引入': 1,
#   '三百年': 1,
#   '防止': 1,
#   '上': 1,
#   '在': 1,
#   '沿': 1,
#   '先': 1,
#   '进行': 1,
#   '穿梭机': 1,
#   '难以想象': 1},
#  '需要一种': {'务实精神': 1},
#  '一种务实精神': {'，': 1},
#  '务实精神，': {'需要': 1},
#  '需要引入': {'更': 1},
#  '引入更': {'巿': 1},
#  '更巿': {'场化': 1},
#  '场化的': {'手段': 1},
#  '的手段': {'，': 3, '。': 1},
#  '手段，': {'因而': 1, '被': 1, '有效': 1, '最': 1},
#  '，因而': {'我们': 1, '出现': 1, '具有': 1, '掌握': 1, '也': 1, '任何': 1, '人类': 1},
#  '因而我们': {'着眼于': 1},
#  '我们着眼于': {'远景': 1},
#  '着眼于远景': {'，': 1},
#  '远景，': {'而': 1},
#  '，而': {'着手': 1,
#   '在': 5,
#   '科学': 1,
#   '狄奥伦娜': 1,
#   '这个': 3,
#   '它': 2,
#   '她': 3,
#   '敌人': 2,
#   '他': 3,
#   '下面': 1,
#   '大脑': 1,
#   '不仅仅': 2,
#   '不是': 4,
#   '包括': 1,
#   '你': 1,
#   '黑暗': 1,
#   '人类': 2,
#   '柔美': 1,
#   '后者': 2,
#   '戴文': 1,
#   '现在': 4,
#   '在于': 1,
#   '第二支': 1,
#   '这': 2,
#   '这时': 1,
#   '火星': 1,
#   '从中': 1,
#   '你们': 1,
#   '参加': 1,
#   '亨特': 2,
#   '身份': 1,
#   '这些': 5,
#   '来自': 1,
#   '此时': 1,
#   '无数': 1,
#   '对此': 1,
#   '这样': 1,
#   '“': 1,
#   '这种': 3,
#   '监视': 1,
#   '使': 1,
#   '类木行星': 1,
#   '应该': 1,
#   '肥皂': 1,
#   '默斯': 2,
#   '黑洞': 1,
#   '按照': 1,
#   '仍': 1,
#   '恒星': 1,
#   '剩下': 1,
#   '飞向': 1,
#   '黑域': 1,
#   '模拟': 1,
#   '维德': 1,
#   '作为': 1,
#   '那': 2,
#   '环日': 1,
#   '支持者': 1,
#   '第一次': 1,
#   '像': 1,
#   '凡': 1,
#   '大多数': 1,
#   '冥王星': 1,
#   '向': 1,
#   '真正': 1},
#  '而着手': {'之处': 1},
#  '着手之处': {'则': 1},
#  '之处则': {'在于': 1},
#  '则在于': {'一块': 1},
#  '在于一块': {' ': 1},
#  '一块 ': {'块': 1},
#  ' 块': {'“': 1},
#  '块“': {'基石': 1, '玻璃': 1},
#  '”。': {'需要': 1,
#   '现在': 1,
#   '胡文': 1,
#   '群星': 1,
#   '他': 1,
#   '与会者': 1,
#   '观测站': 1,
#   '“': 1,
#   '由于': 1,
#   '但': 1,
#   '很快': 1,
#   '紧接着': 1,
#   '在': 1,
#   '有关': 1,
#   '程心': 2,
#   '太空': 1,
#   '有': 1},
#  '。需要': {'特别': 1},
#  '需要特别': {'说明': 1},
#  '特别说明': {'的': 1, '，': 1},
#  '说明的': {'是': 1},
#  '的是': {'，': 26,
#   '一条': 2,
#   '世界': 1,
#   '月球': 1,
#   '这里': 1,
#   '谁': 3,
#   '父亲': 1,
#   '一位': 2,
#   '安乐': 1,
#   '墙上': 1,
#   '保卫': 1,
#   '维德': 2,
#   '象征意义': 1,
#   '把': 1,
#   '什么': 4,
#   '未来': 1,
#   '使用': 1,
#   '控制': 1,
#   '一件': 1,
#   '他': 1,
#   '：': 4,
#   '真心话': 2,
#   '法律': 1,
#   'AA': 2,
#   '威慑': 1,
#   '它们': 1,
#   '实情': 2,
#   '两种': 1,
#   '更加': 2,
#   '已经': 1,
#   '让': 1,
#   '包括': 1,
#   '那些': 1,
#   '引力波': 1,
#   '在': 1,
#   '几罐': 1,
#   '智子': 1,
#   '事实': 1,
#   '一场': 1,
#   '联合国': 1,
#   '一个': 4,
#   '那': 2,
#   '敬佩': 1,
#   '宪兵': 1,
#   '老亨特': 1,
#   '飞船': 1,
#   '“': 2,
#   '相当于': 1,
#   '固体': 1,
#   '有限': 1,
#   '并列': 1,
#   '可能': 1,
#   '汉英': 1,
#   '对': 1,
#   '政治家': 1,
#   '弗雷斯': 1,
#   '三体': 2,
#   '这样': 1,
#   '宇宙': 1,
#   '豪华': 1,
#   '人类': 2,
#   '这团': 1,
#   '自己': 1,
#   '陪同': 1,
#   '来不及': 1,
#   '蓝天': 1,
#   '卫队长': 1,
#   '公主': 1,
#   '宽': 1,
#   '香皂': 1,
#   '轻便': 1,
#   '那颗': 1,
#   '激光': 1,
#   '透镜': 1,
#   '爆发': 1,
#   '掩体': 1,
#   '什么样': 1,
#   '距': 1,
#   '一座': 1,
#   '城市': 1,
#   '一片': 1,
#   '程心': 1,
#   '一辆': 1,
#   '这些': 1,
#   '那个': 1,
#   '中膜': 1,
#   '刚才': 1,
#   '木星': 1,
#   '它': 1,
#   '岩石': 1,
#   '固态': 1,
#   '地球': 1,
#   '凡': 2,
#   '土星': 1,
#   '各种': 1,
#   '二维': 1,
#   '冰冻': 1,
#   '。': 1,
#   '许多': 1,
#   '经过': 1,
#   '空间': 1,
#   '两条': 1,
#   '紫色': 1,
#   '星空': 1,
#   '立': 1,
#   '真话': 1,
#   '真理': 1,
#   '没有': 1},
#  '是，': {'对于': 2,
#   '那': 1,
#   '他': 3,
#   '皇上': 1,
#   '请': 8,
#   '高中同学': 1,
#   '他们': 1,
#   '那个': 3,
#   '有': 2,
#   '我': 4,
#   '种子': 1,
#   '结果': 1,
#   '“': 2,
#   '是': 1,
#   '阶梯': 1,
#   '21': 1,
#   '三体': 1,
#   '当罗辑': 1,
#   '罗辑': 1,
#   '同样': 1,
#   '但': 1,
#   '曾经': 1,
#   '这些': 1,
#   '今年': 1,
#   '随着': 1,
#   '你': 1,
#   '贵金属': 1,
#   '这次': 2,
#   '在': 2,
#   '降低': 1,
#   '董事会': 1,
#   '我们': 1,
#   '这个': 1,
#   '木卫二': 1,
#   '它': 1,
#   '她': 1,
#   '到处': 1,
#   '特别': 1,
#   '想想': 1,
#   '二维': 1,
#   '下面': 1,
#   '宇宙': 1,
#   '还': 1},
#  '，对于': {'基石': 1,
#   '一个': 4,
#   '我': 1,
#   '三体': 1,
#   '他': 1,
#   '来自': 1,
#   '一名': 1,
#   '人类': 1,
#   '这些': 1,
#   '涌进': 1,
#   '三维': 2,
#   '它': 2,
#   '这次': 1,
#   '云': 1,
#   '大多数': 1,
#   '伞': 1,
#   '光速': 1,
#   '城市': 1,
#   '这里': 1,
#   '搞': 1,
#   '引擎': 1,
#   '他们': 1,
#   '宇宙': 1,
#   '归零': 1,
#   '她': 1},
#  '对于基石': {'，': 1},
#  '基石，': {'我们': 1},
#  '我们并': {'没有': 1, '不': 1},
#  '并没有': {'什么': 6,
#   '完全': 2,
#   '看': 2,
#   '降低': 1,
#   '太': 1,
#   '把': 2,
#   '她': 1,
#   '失落': 1,
#   '在': 1,
#   '歧视': 1,
#   '改变': 2,
#   '更': 2,
#   '成为': 1,
#   '感到': 5,
#   '致命': 1,
#   '直接': 1,
#   '使': 1,
#   '消失': 2,
#   '为此': 1,
#   '给': 2,
#   '“': 1,
#   '任何': 1,
#   '准备': 1,
#   '取消': 1,
#   '掌握': 2,
#   '出现': 1,
#   '往日': 1,
#   '感觉': 1,
#   '发生': 1,
#   '让': 1,
#   '持续': 1,
#   '放弃': 1,
#   '到达': 1,
#   '像': 1,
#   '对': 1,
#   '多少': 1,
#   '造成': 1,
#   '明确': 1,
#   '滑': 1,
#   '征得': 1,
#   '在意': 1,
#   '看到': 1,
#   '开动': 1,
#   '对此': 1,
#   '作用': 1,
#   '遭到': 1,
#   '胜诉': 1,
#   '立刻': 1,
#   '太大': 1,
#   '处于': 1,
#   '精确': 1,
#   '进行': 1,
#   '放松': 1,
#   '回答': 1,
#   '限制': 1,
#   '挑选': 1,
#   '去': 1,
#   '近': 1,
#   '与': 2,
#   '明显': 1},
#  '没有什么': {'限定': 1,
#   '破裂': 1,
#   '冲突': 1,
#   '不利': 1,
#   '区别': 2,
#   '太大': 2,
#   '是': 1,
#   '异常': 2,
#   '能': 1,
#   '遗憾': 1,
#   '特别之处': 1,
#   '变化': 1,
#   '更': 1,
#   '不': 1,
#   '不同': 1,
#   '进展': 1,
#   '特别': 1,
#   '能够': 1,
#   '要紧': 1,
#   '东西': 1},
#  '什么限定': {'。': 1},
#  '限定。': {'因为': 1},
#  '。因为': {'，': 1, '在': 1, '三个': 1, '这里': 1, '星空': 1},
#  '因为，': {'要建': 1},
#  '，要建': {'一座': 1},
#  '要建一座': {'大厦': 1},
#  '一座大厦': {'需要': 1, '，': 1},
#  '大厦需要': {'各种各样': 1},
#  '需要各种各样': {'的': 1},
#  '各种各样的': {'石料': 1},
#  '的石料': {'。': 1},
#  '石料。': {'对于': 1},
#  '。对于': {'那样': 1,
#   '这个': 2,
#   '二十多年': 1,
#   '有些': 1,
#   '那个': 1,
#   '一个': 1,
#   '程心': 2,
#   '维德': 1,
#   '瓦季姆': 1,
#   'PIA': 1,
#   '地球': 1,
#   '他们': 1,
#   '智子': 1,
#   '刚才': 1,
#   '用': 1,
#   '三体': 1,
#   '他': 1,
#   '人类': 1,
#   '由': 1,
#   '亲历': 1,
#   '已': 1,
#   '飞行器': 1,
#   '简陋': 1,
#   '利用': 1,
#   '宇宙': 1,
#   '广播': 1,
#   '星': 1,
#   '后': 1,
#   '“': 1,
#   '水星': 1,
#   '自己': 1,
#   '智慧': 1},
#  '对于那样': {'一座': 1},
#  '那样一座': {'大厦': 1},
#  '大厦，': {'我们': 1, '它于': 1, '是': 1},
#  '我们满怀': {'期待': 1},
#  '满怀期待': {'。': 1},
#  '期待。': {'《': 1, '“': 2},
#  '。《': {'三体': 43, '时间': 6},
#  '》 ': {'作者': 52},
#  ' 作者': {'：': 52},
#  '刘慈欣心事': {'浩渺': 1},
#  '心事浩渺': {'连广宇': 1},
#  '浩渺连广宇': {'严锋': 1},
#  '连广宇严锋': {'复旦大学': 1},
#  '严锋复旦大学': {'中文系': 1},
#  '复旦大学中文系': {'副教授': 1},
#  '中文系副教授': {' ': 1},
#  '副教授 ': {'《': 1},
#  ' 《': {'新': 1},
#  '《新': {'发现': 1},
#  '新发现': {'》': 1, '的': 1, '告诉': 1},
#  '发现》': {'杂志': 1},
#  '》杂志': {'主编': 1},
#  '杂志主编': {'多年': 1},
#  '主编多年': {'以后': 1},
#  '多年以后': {'，': 1},
#  '以后，': {'我': 1,
#   '人们': 1,
#   '大病': 1,
#   '不管': 2,
#   '虽然': 1,
#   '程心': 1,
#   '世界': 1,
#   '现在': 1,
#   '形势': 1,
#   '剩下': 1,
#   '两个': 1,
#   '三体': 1,
#   '王国': 1,
#   '她': 1,
#   '他们': 1,
#   '星环': 1,
#   '又': 1,
#   '经常': 1,
#   '在': 2},
#  '，我': {'还': 3,
#   '走出': 1,
#   '的': 26,
#   '个人': 2,
#   '体验': 1,
#   '想': 11,
#   '必须': 1,
#   '认为': 3,
#   '忍不住': 1,
#   '感觉': 2,
#   '不': 7,
#   '…': 2,
#   '打算': 1,
#   '才': 1,
#   '总得': 1,
#   '就': 10,
#   '去': 7,
#   '欠': 1,
#   '永远': 1,
#   '不是': 4,
#   '带': 1,
#   '真的': 1,
#   '快死了': 1,
#   '很少': 1,
#   '很': 1,
#   '希望': 4,
#   '母亲': 1,
#   '有': 2,
#   '他': 1,
#   '不怕死': 1,
#   '只是': 5,
#   '代表': 1,
#   '接受': 2,
#   '回去': 1,
#   '提醒': 1,
#   '交出': 1,
#   '也': 16,
#   '说不清楚': 1,
#   '怀疑': 1,
#   '负责': 1,
#   '可是': 2,
#   '是': 18,
#   '怎么': 3,
#   '此时': 1,
#   '知道': 5,
#   '从': 1,
#   '随意': 1,
#   '不停': 1,
#   '对': 2,
#   '当然': 1,
#   '站': 1,
#   '以前': 2,
#   '连': 1,
#   '求之不得': 1,
#   '在': 3,
#   '发现': 1,
#   '感到': 1,
#   '这么': 1,
#   '观察': 1,
#   '不过': 1,
#   '只': 3,
#   '本来': 2,
#   '肯定': 1,
#   '强烈建议': 1,
#   '一直': 2,
#   '从来': 1,
#   '曾': 2,
#   '首先': 1,
#   '真': 1,
#   '这': 2,
#   '只能': 3,
#   '刚才': 2,
#   '不想': 2,
#   '把': 3,
#   '没有': 1,
#   '正要': 1,
#   '已经': 2,
#   '第一次': 1,
#   '都': 1,
#   '现在': 2,
#   '派': 1,
#   '只要': 1,
#   '带来': 1,
#   '只有': 1,
#   '该当': 1,
#   '这样': 2,
#   '夜里': 1,
#   '父亲': 1,
#   '小时候': 1,
#   '什么': 5,
#   '可以': 3,
#   '就是': 2,
#   '和': 1,
#   '见到': 1,
#   '将': 4,
#   '觉得': 1,
#   '想像': 1,
#   '说': 4,
#   '再': 1,
#   '可不': 1,
#   '年轻': 1,
#   '认识': 1,
#   '远远地': 1,
#   '给': 1,
#   '有权': 1,
#   '到': 1,
#   '不会': 2,
#   '还是': 2,
#   '一年': 1,
#   '遵守': 1,
#   '今天': 1,
#   '总是': 1,
#   '屋里': 1,
#   '还有': 1,
#   '腿脚': 1,
#   '可': 1,
#   '正想': 1,
#   '告诉': 3,
#   '那时': 1,
#   '扶': 1,
#   '五百岁': 1,
#   '留下来': 1,
#   '同样': 1,
#   '过去': 1,
#   '嘛': 1,
#   '从来不': 1,
#   '得到': 1,
#   '成为': 1},
#  '我还': {'会': 2, '见': 1, '听': 1, '抱': 1, '美': 1, '真': 1, '真是': 1},
#  '还会': {'记得': 1, '回来': 1, '这么': 1, '再': 1, '用': 1},
#  '会记得': {'看': 1},
#  '记得看': {'完': 1},
#  '看完': {'《': 1, '故事': 1, '了': 1},
#  '完《': {'三体': 1},
#  '三体》': {'的': 2, '之后': 1, '是': 1, '写': 1, '开始': 1, '对': 1, '及': 1},
#  '》的': {'那个': 1, '起点': 1, '结尾': 2, '写作': 1, '框架': 1, '童话故事': 1, '东西': 1},
#  '的那个': {'秋夜': 1,
#   '圣女': 1,
#   '方向': 1,
#   '女孩': 2,
#   '遥远': 1,
#   '发射器': 1,
#   '，': 1,
#   '窗口': 1,
#   '强大': 1,
#   '男人': 1,
#   '…': 1,
#   '地方': 2,
#   '时代': 5,
#   '宝宝': 1,
#   '清晨': 1,
#   '黎明': 1,
#   '位置': 1,
#   '圆洞': 1,
#   '不可': 1,
#   '数列': 1,
#   '黑暗': 1,
#   '半球': 1,
#   '可能性': 1,
#   '针眼': 1,
#   '巨人': 1,
#   '夜晚': 1,
#   '星系': 1,
#   '点': 1,
#   '罗辑': 1,
#   '血色': 1,
#   '阶段': 1,
#   '生物': 1,
#   '小': 1,
#   '世界': 1,
#   '大': 1,
#   '太阳': 1},
#  '那个秋夜': {'，': 1},
#  '秋夜，': {'我': 1},
#  '我走出': {'家门': 1},
#  '走出家门': {'，': 1},
#  '家门，': {'在': 1, '穿过': 1},
#  '，在': {'小区': 1,
#   '当今': 1,
#   '超越性': 1,
#   '最': 1,
#   '一个': 5,
#   '这里': 9,
#   '欧洲': 2,
#   '大臣': 1,
#   '黑暗': 5,
#   '暗处': 1,
#   '角落': 1,
#   '某些': 1,
#   '已': 1,
#   '铅灰色': 1,
#   '普罗旺斯': 1,
#   '他们': 9,
#   '那里': 6,
#   '路': 1,
#   '塔': 1,
#   '火炬': 1,
#   '昏暗': 4,
#   '对': 1,
#   '那束': 1,
#   '地质': 1,
#   '开始运行': 1,
#   '头版': 1,
#   '死': 2,
#   '微风': 1,
#   '之前': 1,
#   '生物学': 1,
#   '其他': 1,
#   '其中': 2,
#   '本': 1,
#   '当时': 1,
#   '她': 16,
#   '门口': 1,
#   '北京': 1,
#   '错误': 1,
#   '远景': 1,
#   '冰面': 1,
#   '没有': 2,
#   '美': 1,
#   '四': 2,
#   '它': 5,
#   '随后': 1,
#   '零下': 1,
#   '体外循环': 1,
#   '剌': 1,
#   '这方面': 1,
#   '帆': 1,
#   '交错': 1,
#   '每次': 1,
#   '降温': 1,
#   '俄罗斯': 1,
#   '阶梯': 1,
#   '地面': 3,
#   '特别': 1,
#   '微微': 1,
#   '宇宙': 6,
#   '最后': 2,
#   '这个': 18,
#   '地板': 1,
#   '这段': 1,
#   '太阳系': 4,
#   '危机': 5,
#   '太空': 4,
#   '“': 3,
#   '蓝色': 1,
#   '飘浮': 1,
#   '法庭': 1,
#   '舰': 1,
#   '开庭': 1,
#   '我': 4,
#   '失重': 4,
#   '身后': 1,
#   '他': 5,
#   '人类': 1,
#   '为': 2,
#   '大众': 1,
#   '学者': 1,
#   '一团': 1,
#   '过去': 1,
#   '轮换': 1,
#   '使用': 1,
#   '医生': 1,
#   '海王星': 1,
#   '这道': 1,
#   '艾克': 1,
#   '泡': 1,
#   '距': 2,
#   '舰体': 1,
#   '设于': 1,
#   '心理': 1,
#   '亚': 1,
#   '弦': 1,
#   '联合国': 4,
#   '振动': 1,
#   '什么': 1,
#   '两': 1,
#   '那': 2,
#   '整个': 2,
#   '警戒': 1,
#   '这': 13,
#   '海面': 2,
#   '无数双': 1,
#   '后来': 1,
#   '一片': 1,
#   '走出': 1,
#   '夕阳': 1,
#   '磁悬浮': 1,
#   '执剑人': 1,
#   '百分之九十': 1,
#   '所有': 2,
#   '四年': 1,
#   '光速': 1,
#   '进入': 2,
#   '水滴': 1,
#   '舰队': 1,
#   '正午': 1,
#   '丛林中': 1,
#   '移民': 3,
#   '威慑': 1,
#   '运输机': 2,
#   '树丛': 1,
#   '墨尔本': 1,
#   '电影': 1,
#   '这块': 1,
#   '晴朗': 1,
#   '澳大利亚': 4,
#   '剩下': 1,
#   '世界各地': 1,
#   '空寂': 1,
#   '最近': 1,
#   '这暗': 1,
#   '市政厅': 1,
#   '这些': 6,
#   '两公里': 1,
#   '木星': 4,
#   '古代': 1,
#   '战舰': 1,
#   '无法': 1,
#   '冬眠': 2,
#   '这样': 2,
#   '来': 1,
#   '面前': 1,
#   '一角': 1,
#   '群星': 1,
#   '人们': 1,
#   '次声波': 1,
#   '画面': 1,
#   '地球': 2,
#   '空中': 3,
#   '显示': 1,
#   '众目睽睽': 1,
#   '另一侧': 1,
#   '空间': 2,
#   '各个': 3,
#   '第四': 1,
#   '那个': 4,
#   '那一刻': 1,
#   '纸面': 1,
#   '四维': 3,
#   '更': 1,
#   '与': 2,
#   '水洼': 1,
#   '出现': 1,
#   '二十天': 1,
#   '维度': 1,
#   '这场': 1,
#   '大多数': 1,
#   '全球': 1,
#   '纽约': 2,
#   '得知': 1,
#   '伊甸园': 1,
#   '创世纪': 1,
#   '苦苦': 1,
#   '下方': 2,
#   '近': 1,
#   '三十': 1,
#   '阳光': 4,
#   '自由': 1,
#   '港口': 1,
#   '返回': 1,
#   '那项': 1,
#   '以后': 4,
#   '球面': 1,
#   '土地': 1,
#   '手里': 1,
#   '异界': 1,
#   '大部分': 2,
#   '智子': 1,
#   '我们': 2,
#   '心里': 1,
#   '激动': 1,
#   '相当': 1,
#   '简陋': 1,
#   '三个': 2,
#   '等待': 1,
#   '欢歌笑语': 1,
#   '国王': 1,
#   '王后': 1,
#   '周围': 2,
#   '找到': 1,
#   '初露': 1,
#   '那幅': 1,
#   '水中': 1,
#   '火光': 1,
#   '清晨': 1,
#   '雪白': 1,
#   '它们': 1,
#   '早晨': 1,
#   '后面': 1,
#   '海上': 1,
#   '海滩': 1,
#   '前面': 1,
#   '石阶': 1,
#   '王国': 1,
#   '朝阳': 1,
#   '故事': 1,
#   '网络': 1,
#   '太阳': 2,
#   '笼罩着': 1,
#   '这片': 1,
#   '滔滔不绝': 1,
#   'IDC': 2,
#   '委员会': 1,
#   '旋转': 1,
#   '不': 1,
#   '山顶': 1,
#   '西部': 1,
#   '渐暗': 1,
#   '底部': 1,
#   '轰鸣声': 1,
#   '金色': 1,
#   '理论': 1,
#   '通过': 1,
#   '黑域': 1,
#   '远处': 1,
#   '飞船': 4,
#   '嘈杂': 1,
#   '求生': 1,
#   '短时间': 1,
#   '发射': 1,
#   '假': 1,
#   '巨': 1,
#   '接近': 1,
#   '这架': 1,
#   '不知不觉': 1,
#   '那山': 1,
#   '距离': 1,
#   '里面': 1,
#   '试验': 1,
#   '距母': 1,
#   '推送': 1,
#   '一百五十万': 1,
#   '星环': 1,
#   '灯框': 1,
#   '仍然': 1,
#   '不远处': 1,
#   '圆筒': 1,
#   '程心': 1,
#   '进行': 1,
#   '不同': 1,
#   '靠近': 1,
#   '重力': 1,
#   '灯光': 2,
#   '小': 1,
#   '变幻': 1,
#   '土星': 1,
#   '较晚': 1,
#   '由': 1,
#   '巨大': 1,
#   '研究': 1,
#   '只能': 1,
#   '八年': 1,
#   '新': 3,
#   '掩体': 3,
#   '联邦最高法院': 1,
#   '一道': 1,
#   '这粒': 1,
#   '外行': 1,
#   '歌者': 1,
#   '意义': 1,
#   '生存': 1,
#   '圆柱': 1,
#   '围绕': 1,
#   '半个世纪': 1,
#   'PIA': 2,
#   '联邦': 1,
#   '考虑': 1,
#   '近距离': 2,
#   '天线': 1,
#   '四十多分钟': 1,
#   '引力波': 1,
#   '这种': 4,
#   '沙': 1,
#   '身边': 1,
#   '超重': 2,
#   '恒星': 3,
#   '二维': 7,
#   '加速': 1,
#   '匀速': 1,
#   '小型': 1,
#   '星光': 1,
#   '探照灯': 1,
#   '黯淡': 1,
#   '静止': 1,
#   '遥远': 1,
#   '上面': 1,
#   '一只': 1,
#   '太空城': 1,
#   '黄昏': 1,
#   '不到': 1,
#   '无形': 1,
#   '外面': 1,
#   '雪天': 1,
#   '这幅': 1,
#   '红岸': 1,
#   '炽热': 1,
#   '打击': 1,
#   '星图': 1,
#   '航迹': 1,
#   '可见光': 1,
#   '一阵': 1,
#   '男人': 1,
#   '草地': 1,
#   '那些': 1,
#   '二百八十': 1,
#   '监视': 2,
#   '行': 1,
#   '寻找': 1,
#   '时间': 1,
#   '3G': 1,
#   '罗辑': 1,
#   '真正': 1,
#   '超大规模': 1,
#   '三维': 1,
#   '发光': 1,
#   '舱壁': 1,
#   '剧烈': 1,
#   '林间': 1,
#   '低': 1,
#   '林间空地': 1,
#   '表格': 1,
#   '悄悄': 1,
#   '黑色': 1,
#   '空地': 1,
#   '一切': 1,
#   '四面': 1,
#   '任何': 1,
#   '高维': 1,
#   '新纪元': 1,
#   '以前': 1,
#   '彩虹': 1,
#   '一': 1},
#  '在小区': {'里': 1},
#  '小区里': {'盘桓': 1},
#  '里盘桓': {'。': 1},
#  '盘桓。': {'铅灰色': 1},
#  '。铅灰色': {'的': 1},
#  '铅灰色的': {'上海': 1, '天幕': 1},
#  '的上海': {'夜空': 1},
#  '上海夜空': {'几乎': 1},
#  '夜空几乎': {'看不到': 1},
#  '几乎看不到': {'几颗': 1, '驾驶': 1},
#  '看不到几颗': {'星星': 1},
#  '几颗星星': {'，': 1},
#  '星星，': {'但是': 1,
#   '这': 1,
#   '你': 1,
#   '是': 1,
#   '像': 1,
#   '走': 1,
#   '有人': 1,
#   '我': 1,
#   '其': 2,
#   '而是': 1,
#   '“': 1,
#   '但': 2,
#   '只能': 1,
#   '那': 2,
#   '与': 1,
#   '只': 1,
#   '是夜': 1,
#   '我们': 1,
#   '三个': 1,
#   '主核': 1,
#   '像母': 1,
#   '发现': 1,
#   '至少': 1,
#   '证实': 1,
#   '这些': 1,
#   '它们': 2,
#   '掠过': 1,
#   '目送': 1,
#   '现在': 1,
#   '在': 1},
#  '，但是': {'我': 1, '对': 2, '字': 1, '没有': 1, '做': 1},
#  '但是我': {'的': 1},
#  '我的': {'心中': 1,
#   '视觉': 1,
#   '内心': 1,
#   '先祖': 1,
#   '战场': 1,
#   '战争': 1,
#   '头': 1,
#   '一生': 2,
#   '公司': 1,
#   '。': 1,
#   '时间': 1,
#   '大脑': 1,
#   '错': 1,
#   '全部': 1,
#   '那种': 1,
#   '家乡': 1,
#   '导师': 2,
#   '新': 1,
#   '专业': 1,
#   '舱': 1,
#   '工作': 1,
#   '幽闭': 1,
#   '眼睛': 1,
#   '观测站': 1,
#   '世界': 1,
#   '问题': 1,
#   '事': 1,
#   '吗': 1,
#   '童年': 1,
#   '那颗星': 1,
#   '画师': 1,
#   '父王': 2,
#   '王': 16,
#   '老师': 1,
#   '画': 2,
#   '学生': 1,
#   '公主': 5,
#   '大臣': 1,
#   '父母': 1,
#   '宫廷': 1,
#   '向往': 1,
#   '盆': 1,
#   '妹妹': 2,
#   '生命': 1,
#   '剑': 1,
#   '哥哥': 1,
#   '王国': 1,
#   '利剑': 1,
#   '小组': 1,
#   '船': 1,
#   '那个': 1,
#   '打算': 1,
#   '一切': 1,
#   '岁数': 1,
#   '爱恋': 1,
#   '推测': 1,
#   '腿': 1,
#   '感觉': 1,
#   '经历': 2,
#   '！': 1,
#   '责任': 5},
#  '的心中': {'却': 1, '一阵': 1, '却是': 1, '都': 1, '漾': 1, '有': 1, '充满': 1, '升起': 1},
#  '心中却': {'仿佛': 1},
#  '却仿佛': {'有': 1},
#  '仿佛有': {'无限': 1, '一支': 1},
#  '有无限': {'的': 1},
#  '无限的': {'星光': 1, '可能性': 1, '细节': 2, '，': 1, '信息': 1, '发展前景': 1},
#  '的星光': {'在': 1, '中': 2, '；': 1, '，': 2, '。': 3, '微微': 1, '中向': 1},
#  '星光在': {'涌动': 1},
#  '在涌动': {'。': 1},
#  '涌动。': {'这是': 1},
#  '。这是': {'一种': 1,
#   '一个': 15,
#   '一场': 3,
#   '屠龙之': 1,
#   '前所未有': 1,
#   '一只': 1,
#   '人体': 1,
#   '基督教': 1,
#   '最高': 1,
#   '全新': 1,
#   '现代': 1,
#   '一项': 1,
#   '一间': 1,
#   '五个': 1,
#   '一团': 1,
#   '屠杀': 1,
#   '战争': 1,
#   '一些': 1,
#   '人类': 3,
#   '飞船': 1,
#   '一幅': 2,
#   '一艘': 2,
#   '关一帆': 1,
#   '迄今为止': 1,
#   '人口': 1,
#   '程心': 1,
#   '我们': 1,
#   '一位': 1,
#   '全人类': 1,
#   '所有': 1,
#   '三个': 1,
#   '作为': 1,
#   '这颗': 1,
#   '掩体': 1,
#   '贫穷': 1,
#   '太阳系': 1,
#   '一次': 1,
#   '冥王星': 1,
#   '她们': 1,
#   '第一个': 1,
#   '太阳': 1,
#   '个': 3,
#   '再': 1,
#   '云': 1,
#   '另': 1,
#   '继': 1},
#  '这是一种': {'奇异': 1, '十分': 1, '达到': 1, '只有': 1, '放弃': 1},
#  '一种奇异': {'的': 3},
#  '奇异的': {'感受': 1, '庆幸': 1, '感觉': 1, '小': 1, '东西': 1},
#  '的感受': {'，': 1},
#  '感受，': {'我': 1},
#  '的视觉': {'、': 1, '现象': 1, '面对': 1},
#  '视觉、': {'听觉': 1},
#  '、听觉': {'和': 1},
#  '听觉和': {'思维': 1},
#  '和思维': {'好像': 1},
#  '思维好像': {'都': 1},
#  '好像都': {'被': 2},
#  '都被': {'放大': 1,
#   '截断': 1,
#   '锯断': 1,
#   '钉': 1,
#   '布满': 1,
#   '禁止': 1,
#   '强令': 1,
#   '限制': 1,
#   '称为': 1,
#   '取出': 1,
#   '拉进': 1,
#   '完全': 1,
#   '毁灭': 1,
#   '监听': 1,
#   '杀': 1,
#   '烧焦': 1,
#   '画': 1,
#   '啃': 1,
#   '解读': 1,
#   '它': 2,
#   '熔化': 1,
#   '黑洞': 1,
#   '他': 1,
#   '加速': 1,
#   '精确': 1,
#   '照成': 1,
#   '龙卷风': 1},
#  '被放大': {'、': 1},
#  '放大、': {'重组': 1},
#  '、重组': {'和': 1},
#  '重组和': {'牵引': 1},
#  '和牵引': {'，': 1},
#  '牵引，': {'指向': 1},
#  '，指向': {'一个': 1},
#  '指向一个': {'浩渺': 1},
#  '一个浩渺': {'的': 1},
#  '浩渺的': {'所在': 1, '这类': 1, '一个': 1, '太空': 1, '暗红色': 1},
#  '的所在': {'。': 1, '，': 1},
#  '所在。': {'即使': 1},
#  '。即使': {'没有': 3,
#   '是': 2,
# ...
#  '使得三体': {'文明': 1, '世界': 1, '星系': 1},
#  '三体文明': {'的': 2,
#   '是': 1,
#   '也': 2,
#   '保存': 1,
#   '对': 1,
#   '在': 1,
#   '处于': 1,
#   '后来': 1,
#   '已经': 1},
#  '文明的': {'生存条件': 1,
#   '第一': 1,
#   '最': 1,
#   '行动': 1,
#   '崇高': 1,
#   '危机': 1,
#   '敬意': 1,
#   '守护人': 1,
#   '地球': 3,
#   '新纪元': 1,
#   '毁灭': 1,
#   '高福利': 1,
#   '存在': 4,
#   '自残': 1,
#   '极小': 1,
#   '眼中': 1,
#   '坐标': 1,
#   '婴儿': 1,
#   '生存': 1,
#   '方舟': 1,
#   '安全感': 1,
#   '三条': 2,
#   '又': 1,
#   '行为': 1,
#   '一部分': 1,
#   '尽头': 1,
#   '人口数量': 1,
#   '荣誉': 1,
#   '那段': 1,
#   '群体': 1,
#   '生死簿': 1,
#   '语言': 1,
#   '两个': 1,
#   '流星': 1,
#   '历程': 2,
#   '全部': 1},
#  '的生存条件': {'极为': 1},
#  '生存条件极为': {'严酷': 1},
#  '极为严酷': {'。': 1},
#  '严酷。': {'为了': 1, '“': 1},
#  '。为了': {'应对': 1,
#   '调研': 1,
#   '防止': 1,
#   '这次': 1,
#   '安全': 1,
#   '研究': 1,
#   '更': 1,
#   '得到': 1,
#   '照顾': 1,
#   '让': 1,
#   '避免': 1},
#  '为了应对': {'变幻莫测': 1},
#  '应对变幻莫测': {'的': 1},
#  '变幻莫测的': {'自然环境': 1},
#  '的自然环境': {'，': 1},
#  '自然环境，': {'他们': 1},
#  '，他们': {'随时': 1,
#   '不': 3,
#   '证实': 1,
#   '发现': 3,
#   '的': 17,
#   '都': 21,
#   '也': 11,
#   '坠入': 1,
#   '一气之下': 1,
#   '试图': 1,
#   '身着': 1,
#   '所有人': 1,
#   '一起': 1,
#   '就': 2,
#   '把': 4,
#   '扔': 1,
#   '不得不': 1,
#   '自己': 2,
#   '对': 5,
#   '正在': 2,
#   '单独': 1,
#   '无疑': 1,
#   '看到': 4,
#   '很': 2,
#   '会': 5,
#   '中有': 1,
#   '完全': 1,
#   '已': 1,
#   '远远': 1,
#   '和': 2,
#   '告诉': 1,
#   '愿意': 1,
#   '是': 6,
#   '并': 1,
#   '恨': 1,
#   '分布': 1,
#   '在': 8,
#   '虽': 1,
#   '又': 5,
#   '只能': 2,
#   '想': 1,
#   '看上去': 2,
#   '从未': 1,
#   '似乎': 1,
#   '中': 3,
#   '将': 3,
#   '代表': 1,
#   '隔': 1,
#   '可能': 1,
#   '甚至': 2,
#   '可以': 3,
#   '有时': 1,
#   '—': 1,
#   '超量': 1,
#   '保留': 1,
#   '开始': 2,
#   '分成': 1,
#   '大部分': 2,
#   '互存': 1,
#   '应该': 1,
#   '以': 1,
#   '绝对': 1,
#   '替': 1,
#   '正向': 1,
#   '暴露': 1,
#   '至少': 1,
#   '往往': 1,
#   '感受': 1,
#   '想起': 1,
#   '几乎': 1,
#   '只好': 1,
#   '饭前': 1,
#   '成': 1,
#   '每次': 1,
#   '虽然': 1,
#   '谈话': 1,
#   '一直': 1,
#   '用': 2,
#   '表情': 1,
#   '即使': 1,
#   '像': 1,
#   '已经': 3,
#   '现在': 2,
#   '感觉': 1,
#   '向来': 1,
#   '来': 1,
#   '还是': 1,
#   '共': 1,
#   '宣布': 1,
#   '永远': 1,
#   '总是': 1,
#   '绘画': 1,
#   '从中': 1,
#   '不让': 2,
#   '后面': 1,
#   '想到': 1,
#   '拥有': 1,
#   '大都': 1,
#   '中间': 1,
#   '既然': 1,
#   '有': 1,
#   '肯定': 2,
#   '认为': 1,
#   '位于': 1,
#   '正站': 1,
#   '连': 1,
#   '再次': 1,
#   '进入': 1,
#   '每人': 1,
#   '无声': 1,
#   '相视': 1,
#   '或者': 2,
#   '拒绝': 1,
#   '两人': 1,
#   '手拉手': 2,
#   '找': 1,
#   '强调': 1,
#   '没有': 1,
#   '本': 1,
#   '唱': 1,
#   '对此': 1,
#   '能': 1,
#   '真的': 1,
#   '之间': 2,
#   '决定': 1,
#   '悬浮': 1,
#   '正朝': 1,
#   '清楚': 1,
#   '走上': 1,
#   '目光': 1,
#   '仍然': 1,
#   '收到': 1,
#   '绝望': 1,
#   '曾': 1,
#   '向': 1,
#   '转头': 1,
#   '面对': 1,
#   '以为': 1,
#   '向前': 1,
#   '知道': 1,
#   '还': 1,
#   '最': 1,
#   '力图': 1,
#   '觉得': 1},
#  '他们随时': {'可以': 1},
#  '随时可以': {'将': 1, '减速': 1},
#  '可以将': {'自己': 1},
#  '将自己': {'体内': 1, '和': 1},
#  '自己体内': {'的': 1},
#  '体内的': {'水分': 1, '血液': 1, '某种': 1, '小': 1},
#  '的水分': {'完全': 1, '很快': 1},
#  '水分完全': {'排出': 1},
#  '完全排出': {'，': 1},
#  '排出，': {'变成': 1},
#  '，变成': {'干燥': 1,
#   '一片': 2,
#   '另外': 1,
#   '普通': 1,
#   '一位': 1,
#   '一个': 2,
#   '了': 3,
#   '宁静': 1,
#   '一幅': 1,
#   '小镇': 1,
#   '规则': 1,
#   '白色': 1,
#   '黏滞': 1},
#  '变成干燥': {'的': 1},
#  '干燥的': {'纤维状': 1},
#  '的纤维状': {'物体': 1},
#  '纤维状物体': {'，': 1},
#  '物体，': {'以': 1,
#   '长度': 1,
#   '拳头': 1,
#   '而': 1,
#   '由于': 1,
#   '它们': 2,
#   '总计有': 1,
#   '与': 1,
#   '疑似': 1,
#   '借助于': 1,
#   '像': 1,
#   '在': 1,
#   '主体': 1,
#   '除了': 1,
#   '那': 1,
#   '程心': 1,
#   '都': 1},
#  '，以': {'躲过': 1,
#   '她': 1,
#   '一定': 1,
#   '目前': 1,
#   '当时': 1,
#   '模拟': 2,
#   '自己': 1,
#   '监测': 1,
#   '确保': 2,
#   '表明': 1,
#   '令人': 1,
#   '“': 1,
#   '适应': 2,
#   '相差不多': 1,
#   '抵御': 1,
#   '不可思议': 1,
#   '25000': 1,
#   '人类': 1,
#   '与': 1,
#   '维护正义': 1,
#   '汽车': 1,
#   '表示': 1,
#   '柯伊伯': 1,
#   '达到': 1,
#   '避开': 1,
#   '抵消': 1,
#   '三百': 1,
#   '文字': 1,
#   '一个': 1,
#   '增强': 1,
#   '黑洞': 1,
#   '取得': 1,
#   '接近': 1,
#   '一对': 1,
#   '现有': 1,
#   '正确': 1,
#   '太阳': 1,
#   '光速': 2},
#  '以躲过': {'完全': 1},
#  '躲过完全': {'不': 1},
#  '完全不': {'适合': 2, '发光': 1, '可见': 2, '可靠': 1, '可行': 2, '可能': 1, '具备': 1},
#  '不适合': {'生存': 1, '成为': 1, '生命': 1, '远航': 1},
#  '适合生存': {'的': 2},
#  '生存的': {'恶劣': 1,
#   '机会': 1,
#   '诱惑': 1,
#   '人类': 1,
#   '能源需求': 1,
#   '状态': 1,
#   '保证': 1,
#   '障碍': 2,
#   '恒星': 1,
#   '全部': 1,
#   '几率': 1,
#   '环境': 1,
#   '世界': 1},
#  '的恶劣': {'气候': 1},
#  '恶劣气候': {'。': 1},
#  '气候。': {'对于': 1},
#  '对于这个': {'极为': 1, '信息': 1},
#  '这个极为': {'奇幻': 1},
#  '极为奇幻': {'的': 1},
#  '奇幻的': {'想象': 1},
#  '的想象': {'世界': 1, '，': 4, '中': 2, '一点点': 1, '。': 2, '都': 1},
#  '想象世界': {'，': 1},
#  '世界，': {'大': 1,
#   '涵盖': 1,
#   '是否': 1,
#   '她': 1,
#   '这些': 1,
#   '还有': 1,
#   '并': 1,
#   '他们': 3,
#   '一个': 1,
#   '但': 3,
#   '威慑': 1,
#   '杀死': 1,
#   '大众': 1,
#   '必须': 1,
#   '眼前': 1,
#   '不管': 1,
#   '这个': 3,
#   '所有': 1,
#   '其余': 1,
#   '最': 1,
#   '这': 1,
#   '也': 1,
#   '褚岩': 1,
#   '按照': 1,
#   '如果': 2,
#   '回到': 1,
#   '只有': 2,
#   '决定': 1,
#   '是': 1,
#   '任何': 1,
#   '甚至': 1,
#   '那时': 2,
#   '能': 1,
#   '这样': 1,
#   '所以': 2,
#   '那个': 1,
#   '我想': 1,
#   '否则': 1,
#   '倒': 1,
#   '我们': 1,
#   '一张': 1,
#   '当时': 1,
#   '它': 1,
#   '却': 1,
#   '没': 1,
#   '程心': 1,
#   '只不过': 1,
#   '最初': 1,
#   '四下': 1,
#   '在': 2,
#   '走': 1,
#   '其他': 1,
#   '两个': 1,
#   '为了': 1},
#  '刘充分发挥': {'了': 1},
#  '充分发挥了': {'他': 1},
#  '了他': {'在': 2,
#   '的': 10,
#   '离去': 1,
#   '是': 3,
#   '可以': 1,
#   '心中': 1,
#   '冰冷': 1,
#   '，': 5,
#   '！': 1,
#   '―': 1,
#   '。': 4,
#   '都': 1,
#   '说': 1,
#   '超然': 1,
#   '？': 1,
#   '临终前': 1,
#   '最后': 1},
#  '他在': {'硬科学': 1,
#   '工作': 1,
#   '喝': 1,
#   '帮卖': 1,
#   '心里': 1,
#   '讲': 1,
#   '看': 1,
#   '威胁': 1,
#   '提出': 1,
#   '盯': 1,
#   '做': 1,
#   '说': 1,
#   '激活': 1,
#   '欣赏': 1,
#   '地面': 1,
#   '人们': 1,
#   '未来': 1,
#   '失重': 4,
#   '已经': 1,
#   '专心': 1,
#   '这方面': 1,
#   '狂欢': 1,
#   '前面': 1,
#   '起航': 1,
#   '上海': 1,
#   '叫': 1,
#   '麦田': 1,
#   '宴会': 1,
#   '我们': 1,
#   '天边': 1,
#   '台阶': 1,
#   '被': 1,
#   '创造': 1,
#   '研究': 1,
#   '低': 1,
#   '犹豫': 1,
#   '那': 1,
#   '瓶口': 1,
#   '另一侧': 1,
#   '之前': 1},
#  '在硬科学': {'上': 1},
#  '硬科学上': {'的': 1},
#  '上的': {'特长': 1,
#   '三体': 1,
#   '水珠': 1,
#   '一样': 2,
#   '一块': 2,
#   '军人': 1,
#   '泡沫': 1,
#   '大陆': 1,
#   '那些': 1,
#   '按钮': 1,
#   '地址': 1,
#   '，': 5,
#   '人': 11,
#   '一个': 5,
#   '软管': 1,
#   '针头': 1,
#   '缺陷': 2,
#   '首次': 1,
#   '突破': 1,
#   '绝对优势': 1,
#   '每枚': 1,
#   '神经质': 1,
#   '领导': 1,
#   '美国': 1,
#   '人们': 10,
#   '事': 1,
#   '太': 1,
#   '全体官兵': 1,
#   '引力波': 1,
#   '那个': 5,
#   '所有人': 4,
#   '通信': 2,
#   '任何人': 2,
#   '两只': 1,
#   '干库': 1,
#   '雕塑': 1,
#   '人海': 4,
#   '刚': 1,
#   '外太空': 1,
#   '心理医生': 1,
#   '男人': 1,
#   '陆战队': 1,
#   '实时': 1,
#   '破口': 1,
#   'A': 3,
#   '晚霞': 1,
#   '科学家': 2,
#   '和谐': 1,
#   '小小': 1,
#   '早期': 1,
#   '红色': 1,
#   '失误': 1,
#   '澳大利亚': 1,
#   '建筑': 1,
#   '一个个': 1,
#   '折纸': 1,
#   '安宁': 1,
#   '太空城': 1,
#   '人类': 2,
#   '黑巾': 1,
#   '城市': 1,
#   '尸体': 1,
#   '血': 1,
#   '最高': 1,
#   '条件': 1,
#   '士兵': 1,
#   '人员': 3,
#   '许多': 1,
#   '新纪元': 1,
#   '其他': 2,
#   '执剑': 1,
#   '广播': 1,
#   '销毁': 1,
#   '太空': 2,
#   '中尉': 1,
#   '人数': 1,
#   '官兵': 1,
#   '大部分': 2,
#   '程心': 1,
#   '智子': 1,
#   '常规': 1,
#   '一切都是': 1,
#   '一颗': 1,
#   '某处': 1,
#   '圆洞': 1,
#   '科学': 1,
#   '三个': 4,
#   '三人': 1,
#   '银河系': 1,
#   '成员': 1,
#   '人影': 1,
#   '小': 1,
#   '投影': 1,
#   '雪白': 1,
#   '映像': 2,
#   '一片': 1,
#   '三': 1,
#   '真正': 1,
#   '肖像': 1,
#   '色彩': 1,
#   '国王': 1,
#   '光斑': 1,
#   '火把': 1,
#   '白浪': 1,
#   '一艘': 1,
#   '船': 1,
#   '大布': 1,
#   '东西': 2,
#   '岩石': 1,
#   '木盆': 1,
#   '赫尔辛': 2,
#   '两滴': 1,
#   '剑': 1,
#   '蜡烛': 1,
#   '一幅': 1,
#   '已知': 1,
#   '位置': 1,
#   '伞': 1,
#   '一粒': 1,
#   '未知': 1,
#   '巨型': 1,
#   '宗教': 1,
#   '一千多': 1,
#   '小洞': 1,
#   '万吨': 1,
#   '国际': 1,
#   '不': 1,
#   '木头': 1,
#   '坦克': 1,
#   '一小片': 1,
#   '移动': 1,
#   '一个点': 1,
#   '灯': 1,
#   '楼房': 1,
#   '探照灯': 4,
#   '引力': 1,
#   '推进器': 3,
#   '高': 1,
#   '把柄': 1,
#   '加速器': 1,
#   '布置': 1,
#   '几根': 1,
#   '子弹': 1,
#   '主核': 1,
#   '金属': 1,
#   '灵魂': 1,
#   '控制者': 1,
#   '盘子': 1,
#   '监视器': 1,
#   '焰火': 1,
#   '每个': 2,
#   '每': 1,
#   '相当': 1,
#   '箭头': 1,
#   '照明': 1,
#   '图案': 1,
#   '字迹': 1,
#   '一件': 1,
#   '差不多': 1,
#   '生态条件': 1,
#   '一点': 1,
#   '。': 1,
#   '固态': 1,
#   '是': 1,
#   '景观': 1,
#   '水滴': 1,
#   '宁静': 1,
#   '相似': 1,
#   '海洋': 1,
#   '草': 2,
#   '随舰': 1,
#   '生态系统': 1,
#   '基础': 1,
#   '死亡': 1,
#   '照明灯': 1,
#   '时候': 1,
#   '星星': 1,
#   '神经元': 1,
#   '“': 1,
#   '银发': 1,
#   '字': 1,
#   '空泡': 1,
#   '设计': 1,
#   '台风': 1,
#   '精确': 1,
#   '草丛': 1},
#  '的特长': {'，': 1},
#  '特长，': {'賦予': 1},
#  '，賦予': {'这个': 1},
#  '賦予这个': {'世界': 1},
#  '这个世界': {'完全': 1,
#   '最知': 1,
#   '又': 1,
#   '上': 1,
#   '里': 1,
#   '，': 3,
#   '显示': 1,
#   '吧': 1,
#   '已经': 1,
#   '曾经': 1,
#   '升起': 1,
#   '的': 11,
#   '中': 2,
#   '属于': 1,
#   '带来': 2,
#   '。': 1,
#   '是': 2,
#   '几乎': 1,
#   '对': 1,
#   '有电': 1,
#   '包裹': 1,
#   '可以': 1,
#   '生存': 1,
#   '毁灭': 1},
#  '世界完全': {'真实可信': 1},
#  '完全真实可信': {'的': 1},
#  '真实可信的': {'物理': 1},
#  '物理特性': {'和': 1},
#  '特性和': {'演化': 1},
#  '和演化': {'发展': 1},
#  '演化发展': {'规律': 1},
#  '发展规律': {'。': 1},
#  '规律。': {'作为': 1, '”': 4, '宇宙': 1},
#  '。作为': {'一个': 1,
#   '本地人': 1,
#   '极权': 1,
#   '宇航员': 1,
#   '一名': 1,
#   '人类': 1,
#   '环日': 1,
#   '科学考察': 1},
#  '作为一个': {'电脑': 1,
#   '没有': 1,
#   '航天': 1,
#   '知识': 1,
#   '废品': 1,
#   '概念': 1,
#   '普通': 1,
#   '完全': 1},
#  '一个电脑': {'工程师': 1, '査': 1},
#  '电脑工程师': {'，': 1},
#  '工程师，': {'大': 1, '曾到': 1, '也': 1, '那个': 1, '程心': 1, '她': 1, '其实': 1, '用': 1},
#  '刘甚至': {'设计': 1},
#  '甚至设计': {'了': 1},
#  '设计了': {'一个': 1, '这样': 1},
#  '了一个': {'三体': 1,
#   '更': 5,
#   '平静': 1,
#   '让': 1,
#   '摆脱': 1,
#   '卡通': 1,
#   '未来': 1,
#   '惊人': 2,
#   '还': 1,
#   '噩梦': 1,
#   '错误': 1,
#   '微型': 1,
#   '共同点': 1,
#   '实实在在': 1,
#   '世界': 2,
#   '后来': 1,
#   '不可理喻': 1,
#   '爸爸': 1,
#   '太阳': 2,
#   '前哨': 1,
#   '探索': 1,
#   '圆形': 1,
#   '他': 1,
#   '细长': 1,
#   '梦': 1,
#   '地方': 1,
#   '层次': 1,
#   '陌生': 1,
#   '自己': 1,
#   '文明': 2,
#   '地球': 1,
#   '巨型': 1,
#   '宽阔': 1,
#   '在': 2,
#   '三角形': 1,
#   '推进力': 1,
#   '不等边': 1,
#   '全息': 1,
#   '圆孔': 1,
#   '维度': 2,
#   '太空': 1,
#   '跟头': 1,
#   '圆环状': 1,
#   '问候语': 1,
#   '质数': 1,
#   '寒战': 1,
#   '更大': 1,
#   '大弯': 1,
#   '如': 1,
#   '简短': 1,
#   '光度': 1,
#   '字': 1,
#   '危险': 1,
#   '建设': 1,
#   '人们': 1,
#   '宇宙': 1,
#   '球体': 1,
#   '异': 1,
#   '倒计时': 1,
#   '狭窄': 1,
#   '女人': 1,
#   '明确': 1,
#   '小': 3,
#   '无': 1,
#   '哨兵': 1,
#   '正面': 1,
#   '小孔': 1,
#   '坐标': 1,
#   '没有': 1,
#   '语言学': 1,
#   '永远': 1,
#   '怯生生': 1,
#   '洞': 1,
#   '人类': 1,
#   '重要': 3,
#   '稳定': 1,
#   '“': 1,
#   '微缩': 1,
#   '组织': 1,
#   '小房间': 1,
#   '角度': 1,
#   '醒目': 1,
#   '蓝色': 1,
#   '亚洲一号': 1,
#   '发': 1,
#   '环绕': 1,
#   '有': 1,
#   '主核': 1,
#   '不祥': 1,
#   '不安': 1,
#   '不明飞行物': 1,
#   '囊括': 2,
#   '星期': 1,
#   '坑': 1,
#   '小时': 1,
#   '事实': 1,
#   '奇怪': 1,
#   '大': 2,
#   '新': 1,
#   '亮点': 1,
#   '光团': 1,
#   '大坑': 1,
#   '区域': 1,
#   '巨大': 1,
#   '黑色': 1,
#   '世纪': 1,
#   '比较': 1,
#   '小盒': 1,
#   'OK': 1,
#   '变化': 1,
#   '合格': 1,
#   '对': 1,
#   '终端': 1},
#  '一个三体': {'程序': 1},
#  '三体程序': {'，': 1},
#  '程序，': {'来': 1, '老李': 1, '这种': 1, '他': 1},
#  '，来': {'模拟': 1, '的': 1, '解释': 1},
#  '来模拟': {'宇宙': 1, '一个': 1, '整个': 1},
#  '模拟宇宙': {'文明': 1},
#  '宇宙文明': {'间': 1, '。': 1, '的': 2, '中有': 1},
#  '文明间': {'的': 2},
#  '间的': {'相互': 1,
#   '量子': 1,
#   '缝隙': 2,
#   '冲突': 2,
#   '电磁力': 1,
#   '流动': 1,
#   '相对速度': 1,
#   '联系': 1,
#   '引力': 1,
#   '过眼烟云': 1,
#   '空地': 1,
#   '距离': 3,
#   '，': 1,
#   '工程': 1,
#   '音频': 1,
#   '二百八十': 1,
#   '穿梭机': 1,
#   '任何': 1},
#  '的相互': {'关系': 1, '斜靠': 1},
#  '相互关系': {'。': 1},
#  '关系。': {'这是': 1, '”': 2, '张': 1, '一天': 1, '现在': 1},
#  '这是一个': {'游戏': 1,
#   '地球': 1,
#   '在': 1,
#   '与': 1,
#   '直径': 1,
#   '绝对': 1,
#   '伟大': 1,
#   '由': 2,
#   '策划': 1,
#   '十分复杂': 1,
#   '所有': 1,
#   '没有': 1,
#   '爆炸物': 1,
#   '漫长': 1,
#   '大': 1,
#   '画师': 1,
#   '极其重要': 1,
#   '十分': 1,
#   '人类': 1,
#   '人们': 1,
#   '能': 1,
#   '实骏室': 1,
#   '用长': 1,
#   '太空城': 1,
#   '奇特': 1,
#   '单独': 1,
#   '过渡': 1,
#   '标准': 1,
#   '死': 1,
#   '很': 1,
#   '正常': 1,
#   '全封闭': 2,
#   '宇宙': 2,
#   '很小': 1},
#  '一个游戏': {'，': 1},
#  '游戏，': {'游戏': 1, '就': 1, '持续': 1, '他': 1},
#  '，游戏': {'背后': 1, '中': 1},
#  '游戏背后': {'是': 1},
#  '背后是': {'一个': 1},
#  '是一个': {'遥远': 1,
#   '稳重': 1,
#   '白天': 1,
#   '从': 1,
#   '宣传': 1,
#   '推销': 1,
#   '艰难': 1,
#   '冷美人': 1,
#   '凉爽': 1,
#   '年轻': 1,
#   '必须': 1,
#   '小小的': 2,
#   '大大的': 1,
#   '有利': 1,
#   '提高': 1,
#   '完全': 2,
#   '噩梦': 1,
#   '国家': 1,
#   '巨大': 5,
#   '在': 3,
#   '健康人': 1,
#   '，': 1,
#   '冰冻': 1,
#   '完整': 4,
#   '整体': 1,
#   '通信': 1,
#   '…': 1,
#   '居住区': 1,
#   '极其': 1,
#   '绝密': 1,
#   '很': 5,
#   '外星': 1,
#   '球面': 1,
#   '标准': 1,
#   '斜面': 1,
#   '有机': 1,
#   '高位': 1,
#   '人': 1,
#   '何等': 1,
#   '救世主': 1,
#   '守护者': 1,
#   '女人': 1,
#   '错误': 1,
#   '童话': 1,
#   '强大': 1,
#   '冬眠': 1,
#   '土著': 1,
#   '更好': 1,
#   '骨科医生': 1,
#   '黑色': 2,
#   '群体': 1,
#   '潜伏': 1,
#   '极富': 1,
#   '与': 2,
#   '解脱': 1,
#   '亮晶晶': 1,
#   '传奇人物': 1,
#   '共同': 1,
#   '三维空间': 1,
#   '四维': 1,
#   '废墟': 1,
#   '隐约可见': 1,
#   '为了': 1,
#   '宇宙': 2,
#   '极端': 1,
#   '发出': 1,
#   '越想': 1,
#   '沉重': 1,
#   '不': 1,
#   '男声': 1,
#   '短暂': 1,
#   '孤立': 1,
#   '散热': 1,
#   '不会': 1,
#   '水手': 1,
#   '像': 1,
#   '梦': 2,
#   '封闭': 1,
#   '幻想': 1,
#   '公元': 1,
#   '已经': 1,
#   '小': 1,
#   '仅': 1,
#   '划时代': 1,
#   '死亡': 1,
#   '轮回': 1,
#   '直径': 2,
#   '纯': 1,
#   '特例': 1,
#   '童话般': 1,
#   '光点': 1,
#   '大型': 1,
#   '长相': 1,
#   '公开': 1,
#   '高瞻远瞩': 1,
#   '密封': 1,
#   '超导': 1,
#   '坐标': 1,
#   '白色': 1,
#   '控制中心': 1,
#   '安慰': 1,
#   '金属': 2,
#   '黄昏': 1,
#   '大冒险': 1,
#   '能够': 1,
#   '等待': 1,
#   '正在': 1,
#   '用于': 1,
#   '刚能': 1,
#   '透镜': 1,
#   '研究': 1,
#   '寒冷': 1,
#   '世纪': 1,
#   '大': 1,
#   '铁': 1,
#   '黑洞': 1,
#   '文明': 2,
#   '很扁': 1,
#   '操作系统': 1,
#   '独立': 2,
#   '智慧': 1,
#   '无意': 1,
#   '时间': 1,
#   '同样': 1,
#   '正': 1,
#   '穿着': 1,
#   '赠品': 1,
#   '订制': 1,
#   '超膜': 1,
#   '由': 1},
#  '一个遥远': {'星际': 1, '的': 3},
#  '遥远星际': {'文明': 1},
#  '星际文明': {'二百次': 1},
#  '文明二百次': {'毀灭': 1},
#  '二百次毀灭': {'与': 1},
#  '毀灭与': {'重生': 1},
#  '与重生': {'的': 1},
#  '重生的': {'传奇': 1, '感觉': 1},
#  '的传奇': {'，': 1, '又': 1, '永远': 1},
#  '传奇，': {'游戏': 1},
#  '游戏中': {'的': 1, '，': 1},
#  '的人物': {'却是': 1},
#  '人物却是': {'孔子': 1},
#  '却是孔子': {'、': 1},
#  '孔子、': {'墨子': 1},
#  '、墨子': {'、': 1},
#  '墨子、': {'秦始皇': 1},
#  '、秦始皇': {'、': 1},
#  '秦始皇、': {'伽利略': 1},
#  '、伽利略': {'、': 1},
#  '伽利略、': {'葛力': 1},
#  '、葛力': {'高利': 1},
#  '葛力高利': {'教皇': 1},
#  '高利教皇': {'、': 1},
#  '教皇、': {'牛顿': 1},
#  '、牛顿': {'、': 1},
#  '牛顿、': {'爰': 1},
#  '、爰': {'因斯': 1},
#  '爰因斯': {'坦': 1},
#  '因斯坦': {'…': 1},
#  '坦…': {'…': 1},
#  '……': {'古今中外': 1,
#   '可是': 1,
#   '他': 6,
#   '对': 1,
#   '”': 86,
#   '皇帝': 1,
#   '那个': 1,
#   '长大': 1,
#   '一百多年': 1,
#   '除非': 1,
#   '我': 13,
#   '也': 2,
#   '君士坦丁堡': 1,
#   '海洋': 1,
#   '凌晨': 1,
#   '那': 3,
#   '“': 8,
#   '又': 1,
#   '云': 1,
#   '不': 3,
#   '一句': 1,
#   '就是': 2,
#   '怎么': 2,
#   '灵活': 1,
#   '在': 5,
#   '醒后': 1,
#   '即使': 3,
#   '他们': 1,
#   '如果': 4,
#   '周围': 1,
#   '一抹': 1,
#   '想到': 1,
#   '她': 6,
#   '几样': 1,
#   '尼尔': 1,
#   '赛': 1,
#   '总之': 1,
#   '鲍里斯': 1,
#   '法官': 1,
#   '你们': 2,
#   '当然': 4,
#   '都': 1,
#   '明天': 1,
#   '这部': 1,
#   '这个': 1,
#   '这': 4,
#   '时间': 2,
#   '现在': 3,
#   '上校': 1,
#   '还好': 1,
#   '幽闭': 1,
#   '关键': 1,
#   '医生': 1,
#   '与': 1,
#   '天空': 1,
#   '万籁俱寂': 1,
#   '仅': 2,
#   '但': 8,
#   '这是': 2,
#   '其实': 3,
#   '已经': 1,
#   '所有': 1,
#   '其他': 1,
#   '接近': 1,
#   '父母': 1,
#   '是': 1,
#   '呀': 1,
#   '澳大利亚': 1,
#   '程心': 7,
#   '可': 2,
#   '虽然': 1,
#   '《': 1,
#   '与此同时': 1,
#   '王子': 1,
#   '每': 1,
#   '这些': 3,
#   '藏': 1,
#   '快': 1,
#   '至少': 1,
#   '太阳': 2,
#   '公主': 1,
#   '你': 4,
#   '可以': 2,
#   '先': 1,
#   '针眼': 1,
#   '画得': 1,
#   '作者': 1,
#   'AA': 2,
#   '她们': 1,
#   '这时': 3,
#   '赫尔辛': 1,
#   '骑': 1,
#   '魔泡': 1,
#   '从': 1,
#   '灯塔': 1,
#   '我们': 4,
#   '一个': 1,
#   '停泊': 1,
#   '全是': 1,
#   '不过': 4,
#   '约': 1,
#   '他行': 1,
#   '以后': 1,
#   '车': 1,
#   '没容程': 1,
#   '鬼城': 1,
#   '不到': 1,
#   '反正': 1,
#   '有': 2,
#   '歌者': 1,
#   '居然': 1,
#   '歌声': 1,
#   '白': 1,
#   '最后': 1,
#   '杨冬': 1,
#   '没有': 1,
#   '哇': 1,
#   '好像': 2,
#   '要': 1,
#   '同事': 1,
#   '后来': 1,
#   '面对': 1,
#   '看': 1,
#   '好': 1,
#   '哦': 1,
#   '甚至': 1,
#   '’': 1,
#   '太': 1,
#   '下': 1,
#   '18903729': 1,
#   '小': 1,
#   '一百万': 1,
#   '种种': 1},
#  '…古今中外': {'各路人马': 1},
#  '古今中外各路人马': {'走马灯': 1},
#  '各路人马走马灯': {'似的': 1},
#  '走马灯似的': {'上场': 1},
#  '似的上场': {'。': 1},
#  '上场。': {'这是': 1},
#  '这是一场': {'跨越': 1, '漫长': 1, '最': 1, '想象力': 1, '生死': 1},
#  '一场跨越': {'时空': 1},
#  '跨越时空': {'的': 1, '，': 1},
#  '时空的': {'狂欢': 1, '深刻': 1, '薄膜': 1, '旋涡': 1},
#  '的狂欢': {'，': 1},
#  '狂欢，': {'历史': 1},
#  '，历史': {'、': 1},
#  '历史、': {'文革': 1},
#  '、文革': {'、': 1},
#  '文革、': {'三体': 1},
#  '、三体': {'又': 1, '和': 1},
#  '三体又': {'构成': 1},
#  '又构成': {'了': 1},
#  '构成了': {'另': 1, '一个': 7, '人类': 1, '三个': 1},
#  '了另': {'一个': 7, '一位': 1, '一道': 1},
#  '另一个': {'意义': 1,
#   '世界': 8,
#   '方向': 10,
#   '人': 2,
#   '同学': 1,
#   '门': 1,
#   '维度': 2,
#   '时间': 3,
#   '男人': 3,
#   '危险': 1,
#   '名字': 1,
#   '间接': 1,
#   '‘': 1,
#   '事件': 1,
#   '可能': 1,
#   '移民': 1,
#   '白人': 1,
#   '大陆': 1,
#   '声音': 1,
#   '微弱': 1,
#   '问题': 1,
#   '样子': 2,
#   '地方': 3,
#   '液态': 1,
#   '观点': 1,
#   '念头': 1,
#   '更': 2,
#   '旋涡': 1,
#   '小': 2,
#   '穿着': 1,
#   '地面': 1,
#   '上帝': 1,
#   '。': 1,
#   '坐标': 1,
#   '也': 1,
#   '方面': 2,
#   '宇宙': 1,
#   '特点': 1,
#   '窗口': 1,
#   '秘密': 1,
#   '时': 1},
#  '一个意义': {'上': 1},
#  '意义上': {'的': 7, '看': 2, '说': 1},
#  '三体关系': {'，': 1},
#  '关系，': {'它们': 1,
#   '主机': 1,
#   '于维民': 1,
#   '并且': 1,
#   '世界': 1,
#   '两者': 1,
#   '这是': 1,
#   '与': 1},
#  '，它们': {'之间': 4,
#   '的': 17,
#   '每次': 1,
#   '现在': 2,
#   '碰撞': 1,
#   '密密麻麻': 1,
#   '就': 1,
#   '拥有': 2,
#   '很': 1,
#   '不': 1,
#   '悬浮': 1,
#   '分别': 1,
#   '与': 3,
#   '发出': 2,
#   '中间': 1,
#   '并列': 1,
#   '也': 4,
#   '大小不一': 1,
#   '没有': 1,
#   '完全': 1,
#   '进入': 1,
#   '只能': 1,
#   '都': 2,
#   '发光': 1,
#   '见证': 1,
#   '会': 2,
#   '黑色': 1,
#   '立刻': 1,
#   '除了': 1,
#   '在': 3,
#   '是': 2,
#   '升': 1,
#   '那些': 1,
#   '排成': 2,
#   '大多': 1,
#   '远远地': 1,
#   '一般': 1,
#   '联结': 1,
#   '有': 2,
#   '厚度': 1,
#   '像是': 1,
#   '产生': 1,
#   '凝成': 1,
#   '中': 1,
#   '一端': 1,
#   '顶起': 1,
#   '做': 1,
#   '位于': 1,
#   '变成': 1,
#   '滚滚': 1,
#   '最后': 1,
#   '将': 1},
#  '它们之间': {'遥相': 1, '应该': 1, '的': 2, '空间': 1},
#  ...}

# %%
# 对输入进行分字或分词
start_text = "程心觉得"
gen_len = 200
topn = 3

if split_mode == "char":
    word_list = [char for char in start_text]
elif split_mode == "jieba":
    word_list = [word for word in jieba.cut(start_text)]

# gen_len是我们期望的生成字数或词数
for i in range(gen_len):
    temp_list = []
    # 统计给定前小于等于n-1个词的情况下，下一个词的词频分布
    for j in range(1, ngram_len):
        if j >= len(word_list):
            continue
        prefix = "".join(word_list[-(j + 1):])
        if prefix in ngram_dict:
            temp_list.extend(ngram_dict[prefix].items())
    # 按词频对词排序
    temp_list = sorted(temp_list, key=lambda d: d[1], reverse=True)
    next_word = random.choice(temp_list[:topn])[0]
    word_list.append(next_word)
   
print("".join(word_list))
# Out:
# 程心觉得这架飞行器简直就是一个思想钢印。史耐德：是的。“我们不可能看到。“你的。”关一帆问。“你是怎么处理遗体的贮存和分配等工作。云天明，孤僻离群，事业和生活，他是谁，这就是宇宙安全声明的可能性。第一次经历失重并没有什么异常。刚才我们从翘曲点只能稳定一段时间，虽然在服刑，还是别的什么原因。所以，人们也看到，不过她知道，我的王，画完了，我的公主，我也知道是怎么回事，谁也不可能看到。”“你是说：这是我的责任。在威慑建立之后，又是一个很好。”“我的王，全记住了，她的星星……我有威慑力吗？！”“你是说，他在失重中。“我们不知道，我是墓地，我的公主，那就意味着引擎产生的，在这个过程
